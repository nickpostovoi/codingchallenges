# %%
#import necessary libraries
from sklearn.preprocessing import MinMaxScaler
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import *
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping   
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import RootMeanSquaredError
from tensorflow.keras.optimizers import Adam
from sklearn import metrics
from tensorflow.keras.models import load_model
import os

import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'serif'
plt.rcParams['font.size'] = 12

import mysql.connector
import pandas as pd
import numpy as np

# %% [markdown]
# ### Daily data

# %%
db_connection = mysql.connector.connect(
  host="",
  user="",
  passwd="",
  database="mps_data"
)
cursor = db_connection.cursor()

query = '''
SELECT
    DATE_FORMAT(u.date_time, '%Y-%m-%d 00:00:00') as date, 
    COUNT(*) as count,
    MAX(t.boxing_day) as boxing_day,
    MAX(t.boxing_day_obs) as boxing_day_obs,
    MAX(t.christmas_day) as christmas_day,
    MAX(t.christmas_day_obs) as christmas_day_obs,
    MAX(t.good_friday) as good_friday,
    MAX(t.may_day) as may_day,
    MAX(t.new_years_day) as new_years_day,
    MAX(t.new_years_day_obs) as new_years_day_obs,
    MAX(t.platinum_jubilee) as platinum_jubilee,
    MAX(t.spring_bank_holiday) as spring_bank_holiday,
    MAX(t.state_funeral) as state_funeral,
    MAX(t.outlier) as outlier
FROM use_of_force u
INNER JOIN rq3_add_variables t ON DATE_FORMAT(u.date_time, '%Y-%m-%d 00:00:00') = t.date
WHERE u.date_time > '2019-01-01 00:00:00' AND u.PrimaryConduct > 0
GROUP BY DATE_FORMAT(u.date_time, '%Y-%m-%d 00:00:00');
'''
time_series_daily = pd.read_sql(query, db_connection)

#scale the data
scaler = MinMaxScaler()
time_series_daily['count'] = scaler.fit_transform(time_series_daily[['count']])
#prepare the data for LSTM
time_series_daily['date'] = pd.to_datetime(time_series_daily['date'])
time_series_daily = time_series_daily.set_index('date')  
df = time_series_daily[['count', 'boxing_day', 'boxing_day_obs', 'christmas_day',
       'christmas_day_obs', 'good_friday', 'may_day', 'new_years_day',
       'new_years_day_obs', 'platinum_jubilee', 'spring_bank_holiday',
       'state_funeral', 'outlier']].values
# Out:
# C:\Users\Nikita\AppData\Local\Temp/ipykernel_16808/1753047206.py:30: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   time_series_daily = pd.read_sql(query, db_connection)

# %%
#define a function to create the datasets compatible with LSTM model
def to_sequences(seq_size, obs):
    x = []
    y = []
    #loop through the data set and create the sequences
    for i in range(len(obs)-seq_size):
        window = obs[i:(i+seq_size)]
        after_window = obs[i+seq_size, 0]
        x.append(window)
        y.append(after_window)
    #return the arrays
    return np.array(x),np.array(y)
#define the sequence length (window size)
sequence_size = 30
#call the function to create the datasets
x, y = to_sequences(sequence_size, df)

# %%
#split data into train and test sets
train_test_split_index = len(x) - 60
x_train = x[:train_test_split_index]
y_train = y[:train_test_split_index]
x_test = x[train_test_split_index:]
y_test = y[train_test_split_index:]
#display shapes of train and test sets
print("Shape of training set: {}".format(x_train.shape))
print("Shape of test set: {}".format(x_test.shape))
# Out:
# Shape of training set: (1096, 30, 13)
# Shape of test set: (60, 30, 13)

# %%
#define the model architecture
model = Sequential()
model.add(InputLayer((x_test.shape[1], x_test.shape[2])))
model.add(LSTM(500, activation='tanh', return_sequences=True))
model.add(Dropout(0.1))
model.add(LSTM(500, activation='tanh'))
model.add(Dense(100, 'relu'))
model.add(Dense(1, 'linear'))
#display model summary
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 30, 500)           1028000
#
#  dropout (Dropout)           (None, 30, 500)           0
#
#  lstm_1 (LSTM)               (None, 500)               2002000
#
#  dense (Dense)               (None, 100)               50100
#
#  dense_1 (Dense)             (None, 1)                 101
#
# =================================================================
# Total params: 3,080,201
# Trainable params: 3,080,201
# Non-trainable params: 0
# _________________________________________________________________

# %%
#make sure there is a folder to store the checkpoints, create one if not exist
os.makedirs("checkpoints_LSTM_daily", exist_ok=True)
#define the checkpoint callback saving weights at each epoch
model_checkpoint = ModelCheckpoint('checkpoints_LSTM_daily/model_epoch_{epoch:02d}.h5', 
                                   monitor='val_loss', verbose=1, save_best_only=False, mode='min')
#compile the model
model.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.0001))
#fit the model with early stopping saving history of the training
history = model.fit(x_train, y_train, validation_split=0.2, shuffle=False, epochs=300, 
                     batch_size=8, callbacks=[model_checkpoint, 
                                              keras.callbacks.EarlyStopping(patience=50, restore_best_weights=True)])
# Out:
# Epoch 1/300
# 110/110 [==============================] - ETA: 0s - loss: 0.0110
# Epoch 1: saving model to checkpoints_LSTM_agg_holidays\model_epoch_01.h5
# 110/110 [==============================] - 5s 18ms/step - loss: 0.0110 - val_loss: 0.0081
# Epoch 2/300
# 109/110 [============================>.] - ETA: 0s - loss: 0.0081
# Epoch 2: saving model to checkpoints_LSTM_agg_holidays\model_epoch_02.h5
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0081 - val_loss: 0.0079
# Epoch 3/300
# 109/110 [============================>.] - ETA: 0s - loss: 0.0081
# Epoch 3: saving model to checkpoints_LSTM_agg_holidays\model_epoch_03.h5
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0081 - val_loss: 0.0078
# Epoch 4/300
# 109/110 [============================>.] - ETA: 0s - loss: 0.0080
# Epoch 4: saving model to checkpoints_LSTM_agg_holidays\model_epoch_04.h5
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0080 - val_loss: 0.0079
# Epoch 5/300
# 109/110 [============================>.] - ETA: 0s - loss: 0.0080
# Epoch 5: saving model to checkpoints_LSTM_agg_holidays\model_epoch_05.h5
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0080 - val_loss: 0.0079
# Epoch 6/300
# 109/110 [============================>.] - ETA: 0s - loss: 0.0079
# Epoch 6: saving model to checkpoints_LSTM_agg_holidays\model_epoch_06.h5
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0079 - val_loss: 0.0080
# Epoch 7/300
# 109/110 [============================>.] - ETA: 0s - loss: 0.0079
# Epoch 7: saving model to checkpoints_LSTM_agg_holidays\model_epoch_07.h5
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0079 - val_loss: 0.0080
# Epoch 8/300
# 109/110 [============================>.] - ETA: 0s - loss: 0.0078
# Epoch 8: saving model to checkpoints_LSTM_agg_holidays\model_epoch_08.h5
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0078 - val_loss: 0.0079
# Epoch 9/300
# 109/110 [============================>.] - ETA: 0s - loss: 0.0078
# Epoch 9: saving model to checkpoints_LSTM_agg_holidays\model_epoch_09.h5
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0078 - val_loss: 0.0079
# Epoch 10/300
# 109/110 [============================>.] - ETA: 0s - loss: 0.0078
# Epoch 10: saving model to checkpoints_LSTM_agg_holidays\model_epoch_10.h5
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0078 - val_loss: 0.0079
# Epoch 11/300
# 109/110 [============================>.] - ETA: 0s - loss: 0.0077
# Epoch 11: saving model to checkpoints_LSTM_agg_holidays\model_epoch_11.h5
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0077 - val_loss: 0.0080
# Epoch 12/300
# 109/110 [============================>.] - ETA: 0s - loss: 0.0076
# Epoch 12: saving model to checkpoints_LSTM_agg_holidays\model_epoch_12.h5
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0077 - val_loss: 0.0081
# Epoch 13/300
# 109/110 [============================>.] - ETA: 0s - loss: 0.0076
# Epoch 13: saving model to checkpoints_LSTM_agg_holidays\model_epoch_13.h5
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0076 - val_loss: 0.0081
# Epoch 14/300
# 109/110 [============================>.] - ETA: 0s - loss: 0.0075
# Epoch 14: saving model to checkpoints_LSTM_agg_holidays\model_epoch_14.h5
# 110/110 [==============================] - 1s 10ms/step - loss: 0.0075 - val_loss: 0.0080
# Epoch 15/300
# 109/110 [============================>.] - ETA: 0s - loss: 0.0076
# Epoch 15: saving model to checkpoints_LSTM_agg_holidays\model_epoch_15.h5
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0076 - val_loss: 0.0077
# Epoch 16/300
# 109/110 [============================>.] - ETA: 0s - loss: 0.0074
# Epoch 16: saving model to checkpoints_LSTM_agg_holidays\model_epoch_16.h5
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0074 - val_loss: 0.0080
# Epoch 17/300
# 109/110 [============================>.] - ETA: 0s - loss: 0.0074
# Epoch 17: saving model to checkpoints_LSTM_agg_holidays\model_epoch_17.h5
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0074 - val_loss: 0.0079
# Epoch 18/300
# 109/110 [============================>.] - ETA: 0s - loss: 0.0074
# Epoch 18: saving model to checkpoints_LSTM_agg_holidays\model_epoch_18.h5
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0074 - val_loss: 0.0080
# Epoch 19/300
# 109/110 [============================>.] - ETA: 0s - loss: 0.0073
# Epoch 19: saving model to checkpoints_LSTM_agg_holidays\model_epoch_19.h5
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0073 - val_loss: 0.0079
# Epoch 20/300
# 109/110 [============================>.] - ETA: 0s - loss: 0.0072
# Epoch 20: saving model to checkpoints_LSTM_agg_holidays\model_epoch_20.h5
# 110/110 [==============================] - 1s 10ms/step - loss: 0.0072 - val_loss: 0.0079
# Epoch 21/300
# 109/110 [============================>.] - ETA: 0s - loss: 0.0073
# Epoch 21: saving model to checkpoints_LSTM_agg_holidays\model_epoch_21.h5
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0073 - val_loss: 0.0079
# Epoch 22/300
# 109/110 [============================>.] - ETA: 0s - loss: 0.0071
# Epoch 22: saving model to checkpoints_LSTM_agg_holidays\model_epoch_22.h5
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0071 - val_loss: 0.0080
# Epoch 23/300
# 109/110 [============================>.] - ETA: 0s - loss: 0.0071
# Epoch 23: saving model to checkpoints_LSTM_agg_holidays\model_epoch_23.h5
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0071 - val_loss: 0.0080
# Epoch 24/300
# 109/110 [============================>.] - ETA: 0s - loss: 0.0070
# Epoch 24: saving model to checkpoints_LSTM_agg_holidays\model_epoch_24.h5
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0070 - val_loss: 0.0079
# Epoch 25/300
# 109/110 [============================>.] - ETA: 0s - loss: 0.0069
# Epoch 25: saving model to checkpoints_LSTM_agg_holidays\model_epoch_25.h5
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0069 - val_loss: 0.0079
# Epoch 26/300
# 109/110 [============================>.] - ETA: 0s - loss: 0.0068
# Epoch 26: saving model to checkpoints_LSTM_agg_holidays\model_epoch_26.h5
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0069 - val_loss: 0.0079
# Epoch 27/300
# 109/110 [============================>.] - ETA: 0s - loss: 0.0069
# Epoch 27: saving model to checkpoints_LSTM_agg_holidays\model_epoch_27.h5
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0069 - val_loss: 0.0078
# Epoch 28/300
# 109/110 [============================>.] - ETA: 0s - loss: 0.0068
# Epoch 28: saving model to checkpoints_LSTM_agg_holidays\model_epoch_28.h5
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0068 - val_loss: 0.0079
# Epoch 29/300
# 109/110 [============================>.] - ETA: 0s - loss: 0.0069
# Epoch 29: saving model to checkpoints_LSTM_agg_holidays\model_epoch_29.h5
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0069 - val_loss: 0.0072
# Epoch 30/300
# 109/110 [============================>.] - ETA: 0s - loss: 0.0067
# Epoch 30: saving model to checkpoints_LSTM_agg_holidays\model_epoch_30.h5
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0067 - val_loss: 0.0079
# Epoch 31/300
# 109/110 [============================>.] - ETA: 0s - loss: 0.0067
# Epoch 31: saving model to checkpoints_LSTM_agg_holidays\model_epoch_31.h5
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0067 - val_loss: 0.0077
# Epoch 32/300
# 109/110 [============================>.] - ETA: 0s - loss: 0.0067
# Epoch 32: saving model to checkpoints_LSTM_agg_holidays\model_epoch_32.h5
# 110/110 [==============================] - 1s 10ms/step - loss: 0.0067 - val_loss: 0.0084
# Epoch 33/300
# 109/110 [============================>.] - ETA: 0s - loss: 0.0067
# Epoch 33: saving model to checkpoints_LSTM_agg_holidays\model_epoch_33.h5
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0067 - val_loss: 0.0079
# Epoch 34/300
# 109/110 [============================>.] - ETA: 0s - loss: 0.0065
# Epoch 34: saving model to checkpoints_LSTM_agg_holidays\model_epoch_34.h5
# 110/110 [==============================] - 1s 10ms/step - loss: 0.0065 - val_loss: 0.0081
# Epoch 35/300
# 109/110 [============================>.] - ETA: 0s - loss: 0.0066
# Epoch 35: saving model to checkpoints_LSTM_agg_holidays\model_epoch_35.h5
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0066 - val_loss: 0.0075
# Epoch 36/300
# 109/110 [============================>.] - ETA: 0s - loss: 0.0065
# Epoch 36: saving model to checkpoints_LSTM_agg_holidays\model_epoch_36.h5
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0065 - val_loss: 0.0078
# Epoch 37/300
# 109/110 [============================>.] - ETA: 0s - loss: 0.0064
# Epoch 37: saving model to checkpoints_LSTM_agg_holidays\model_epoch_37.h5
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0064 - val_loss: 0.0077
# Epoch 38/300
# 109/110 [============================>.] - ETA: 0s - loss: 0.0065
# Epoch 38: saving model to checkpoints_LSTM_agg_holidays\model_epoch_38.h5
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0065 - val_loss: 0.0077
# Epoch 39/300
# 109/110 [============================>.] - ETA: 0s - loss: 0.0063
# Epoch 39: saving model to checkpoints_LSTM_agg_holidays\model_epoch_39.h5
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0063 - val_loss: 0.0074
# Epoch 40/300
# 109/110 [============================>.] - ETA: 0s - loss: 0.0065
# Epoch 40: saving model to checkpoints_LSTM_agg_holidays\model_epoch_40.h5
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0065 - val_loss: 0.0072
# Epoch 41/300
# 109/110 [============================>.] - ETA: 0s - loss: 0.0065
# Epoch 41: saving model to checkpoints_LSTM_agg_holidays\model_epoch_41.h5
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0065 - val_loss: 0.0070
# Epoch 42/300
# 109/110 [============================>.] - ETA: 0s - loss: 0.0064
# Epoch 42: saving model to checkpoints_LSTM_agg_holidays\model_epoch_42.h5
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0064 - val_loss: 0.0074
# Epoch 43/300
# 109/110 [============================>.] - ETA: 0s - loss: 0.0063
# Epoch 43: saving model to checkpoints_LSTM_agg_holidays\model_epoch_43.h5
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0063 - val_loss: 0.0068
# Epoch 44/300
# 109/110 [============================>.] - ETA: 0s - loss: 0.0064
# Epoch 44: saving model to checkpoints_LSTM_agg_holidays\model_epoch_44.h5
# 110/110 [==============================] - 1s 10ms/step - loss: 0.0064 - val_loss: 0.0070
# Epoch 45/300
# 109/110 [============================>.] - ETA: 0s - loss: 0.0063
# Epoch 45: saving model to checkpoints_LSTM_agg_holidays\model_epoch_45.h5
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0063 - val_loss: 0.0068
# Epoch 46/300
# 109/110 [============================>.] - ETA: 0s - loss: 0.0062
# Epoch 46: saving model to checkpoints_LSTM_agg_holidays\model_epoch_46.h5
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0062 - val_loss: 0.0067
# Epoch 47/300
# 109/110 [============================>.] - ETA: 0s - loss: 0.0062
# Epoch 47: saving model to checkpoints_LSTM_agg_holidays\model_epoch_47.h5
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0062 - val_loss: 0.0067
# Epoch 48/300
# 109/110 [============================>.] - ETA: 0s - loss: 0.0064
# Epoch 48: saving model to checkpoints_LSTM_agg_holidays\model_epoch_48.h5
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0063 - val_loss: 0.0069
# Epoch 49/300
# 109/110 [============================>.] - ETA: 0s - loss: 0.0062
# Epoch 49: saving model to checkpoints_LSTM_agg_holidays\model_epoch_49.h5
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0062 - val_loss: 0.0064
# Epoch 50/300
# 109/110 [============================>.] - ETA: 0s - loss: 0.0061
# Epoch 50: saving model to checkpoints_LSTM_agg_holidays\model_epoch_50.h5
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0061 - val_loss: 0.0062
# Epoch 51/300
# 109/110 [============================>.] - ETA: 0s - loss: 0.0060
# Epoch 51: saving model to checkpoints_LSTM_agg_holidays\model_epoch_51.h5
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0060 - val_loss: 0.0063
# Epoch 52/300
# 109/110 [============================>.] - ETA: 0s - loss: 0.0061
# Epoch 52: saving model to checkpoints_LSTM_agg_holidays\model_epoch_52.h5
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0061 - val_loss: 0.0063
# Epoch 53/300
# 109/110 [============================>.] - ETA: 0s - loss: 0.0059
# Epoch 53: saving model to checkpoints_LSTM_agg_holidays\model_epoch_53.h5
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0059 - val_loss: 0.0060
# Epoch 54/300
# 109/110 [============================>.] - ETA: 0s - loss: 0.0059
# Epoch 54: saving model to checkpoints_LSTM_agg_holidays\model_epoch_54.h5
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0059 - val_loss: 0.0058
# Epoch 55/300
# 109/110 [============================>.] - ETA: 0s - loss: 0.0059
# Epoch 55: saving model to checkpoints_LSTM_agg_holidays\model_epoch_55.h5
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0058 - val_loss: 0.0059
# Epoch 56/300
# 109/110 [============================>.] - ETA: 0s - loss: 0.0058
# Epoch 56: saving model to checkpoints_LSTM_agg_holidays\model_epoch_56.h5
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0058 - val_loss: 0.0059
# Epoch 57/300
# 109/110 [============================>.] - ETA: 0s - loss: 0.0057
# Epoch 57: saving model to checkpoints_LSTM_agg_holidays\model_epoch_57.h5
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0057 - val_loss: 0.0058
# Epoch 58/300
# 109/110 [============================>.] - ETA: 0s - loss: 0.0057
# Epoch 58: saving model to checkpoints_LSTM_agg_holidays\model_epoch_58.h5
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0057 - val_loss: 0.0060
# Epoch 59/300
# 109/110 [============================>.] - ETA: 0s - loss: 0.0057
# Epoch 59: saving model to checkpoints_LSTM_agg_holidays\model_epoch_59.h5
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0057 - val_loss: 0.0059
# Epoch 60/300
# 109/110 [============================>.] - ETA: 0s - loss: 0.0058
# Epoch 60: saving model to checkpoints_LSTM_agg_holidays\model_epoch_60.h5
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0058 - val_loss: 0.0061
# Epoch 61/300
# 109/110 [============================>.] - ETA: 0s - loss: 0.0058
# Epoch 61: saving model to checkpoints_LSTM_agg_holidays\model_epoch_61.h5
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0057 - val_loss: 0.0060
# Epoch 62/300
# 109/110 [============================>.] - ETA: 0s - loss: 0.0057
# Epoch 62: saving model to checkpoints_LSTM_agg_holidays\model_epoch_62.h5
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0057 - val_loss: 0.0061
# Epoch 63/300
# 109/110 [============================>.] - ETA: 0s - loss: 0.0056
# Epoch 63: saving model to checkpoints_LSTM_agg_holidays\model_epoch_63.h5
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0056 - val_loss: 0.0061
# Epoch 64/300
# 109/110 [============================>.] - ETA: 0s - loss: 0.0055
# Epoch 64: saving model to checkpoints_LSTM_agg_holidays\model_epoch_64.h5
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0055 - val_loss: 0.0057
# Epoch 65/300
# 108/110 [============================>.] - ETA: 0s - loss: 0.0056
# Epoch 65: saving model to checkpoints_LSTM_agg_holidays\model_epoch_65.h5
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0055 - val_loss: 0.0059
# Epoch 66/300
# 109/110 [============================>.] - ETA: 0s - loss: 0.0055
# Epoch 66: saving model to checkpoints_LSTM_agg_holidays\model_epoch_66.h5
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0055 - val_loss: 0.0057
# Epoch 67/300
# 109/110 [============================>.] - ETA: 0s - loss: 0.0055
# Epoch 67: saving model to checkpoints_LSTM_agg_holidays\model_epoch_67.h5
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0055 - val_loss: 0.0059
# Epoch 68/300
# 109/110 [============================>.] - ETA: 0s - loss: 0.0055
# Epoch 68: saving model to checkpoints_LSTM_agg_holidays\model_epoch_68.h5
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0054 - val_loss: 0.0059
# Epoch 69/300
# 108/110 [============================>.] - ETA: 0s - loss: 0.0055
# Epoch 69: saving model to checkpoints_LSTM_agg_holidays\model_epoch_69.h5
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0055 - val_loss: 0.0056
# Epoch 70/300
# 109/110 [============================>.] - ETA: 0s - loss: 0.0053
# Epoch 70: saving model to checkpoints_LSTM_agg_holidays\model_epoch_70.h5
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0053 - val_loss: 0.0059
# Epoch 71/300
# 109/110 [============================>.] - ETA: 0s - loss: 0.0054
# Epoch 71: saving model to checkpoints_LSTM_agg_holidays\model_epoch_71.h5
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0053 - val_loss: 0.0059
# Epoch 72/300
# 109/110 [============================>.] - ETA: 0s - loss: 0.0055
# Epoch 72: saving model to checkpoints_LSTM_agg_holidays\model_epoch_72.h5
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0055 - val_loss: 0.0058
# Epoch 73/300
# 109/110 [============================>.] - ETA: 0s - loss: 0.0054
# Epoch 73: saving model to checkpoints_LSTM_agg_holidays\model_epoch_73.h5
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0054 - val_loss: 0.0059
# Epoch 74/300
# 109/110 [============================>.] - ETA: 0s - loss: 0.0054
# Epoch 74: saving model to checkpoints_LSTM_agg_holidays\model_epoch_74.h5
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0053 - val_loss: 0.0061
# Epoch 75/300
# 109/110 [============================>.] - ETA: 0s - loss: 0.0054
# Epoch 75: saving model to checkpoints_LSTM_agg_holidays\model_epoch_75.h5
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0054 - val_loss: 0.0056
# Epoch 76/300
# 109/110 [============================>.] - ETA: 0s - loss: 0.0053
# Epoch 76: saving model to checkpoints_LSTM_agg_holidays\model_epoch_76.h5
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0053 - val_loss: 0.0054
# Epoch 77/300
# 109/110 [============================>.] - ETA: 0s - loss: 0.0053
# Epoch 77: saving model to checkpoints_LSTM_agg_holidays\model_epoch_77.h5
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0053 - val_loss: 0.0055
# Epoch 78/300
# 109/110 [============================>.] - ETA: 0s - loss: 0.0053
# Epoch 78: saving model to checkpoints_LSTM_agg_holidays\model_epoch_78.h5
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0053 - val_loss: 0.0056
# Epoch 79/300
# 109/110 [============================>.] - ETA: 0s - loss: 0.0055
# Epoch 79: saving model to checkpoints_LSTM_agg_holidays\model_epoch_79.h5
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0055 - val_loss: 0.0061
# Epoch 80/300
# 109/110 [============================>.] - ETA: 0s - loss: 0.0054
# Epoch 80: saving model to checkpoints_LSTM_agg_holidays\model_epoch_80.h5
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0053 - val_loss: 0.0056
# Epoch 81/300
# 109/110 [============================>.] - ETA: 0s - loss: 0.0052
# Epoch 81: saving model to checkpoints_LSTM_agg_holidays\model_epoch_81.h5
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0052 - val_loss: 0.0058
# Epoch 82/300
# 109/110 [============================>.] - ETA: 0s - loss: 0.0052
# Epoch 82: saving model to checkpoints_LSTM_agg_holidays\model_epoch_82.h5
# 110/110 [==============================] - 1s 10ms/step - loss: 0.0051 - val_loss: 0.0056
# Epoch 83/300
# 109/110 [============================>.] - ETA: 0s - loss: 0.0052
# Epoch 83: saving model to checkpoints_LSTM_agg_holidays\model_epoch_83.h5
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0052 - val_loss: 0.0055
# Epoch 84/300
# 109/110 [============================>.] - ETA: 0s - loss: 0.0053
# Epoch 84: saving model to checkpoints_LSTM_agg_holidays\model_epoch_84.h5
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0053 - val_loss: 0.0060
# Epoch 85/300
# 109/110 [============================>.] - ETA: 0s - loss: 0.0054
# Epoch 85: saving model to checkpoints_LSTM_agg_holidays\model_epoch_85.h5
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0054 - val_loss: 0.0055
# Epoch 86/300
# 109/110 [============================>.] - ETA: 0s - loss: 0.0056
# Epoch 86: saving model to checkpoints_LSTM_agg_holidays\model_epoch_86.h5
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0056 - val_loss: 0.0061
# Epoch 87/300
# 109/110 [============================>.] - ETA: 0s - loss: 0.0053
# Epoch 87: saving model to checkpoints_LSTM_agg_holidays\model_epoch_87.h5
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0053 - val_loss: 0.0055
# Epoch 88/300
# 109/110 [============================>.] - ETA: 0s - loss: 0.0054
# Epoch 88: saving model to checkpoints_LSTM_agg_holidays\model_epoch_88.h5
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0054 - val_loss: 0.0059
# Epoch 89/300
# 109/110 [============================>.] - ETA: 0s - loss: 0.0051
# Epoch 89: saving model to checkpoints_LSTM_agg_holidays\model_epoch_89.h5
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0051 - val_loss: 0.0055
# Epoch 90/300
# 109/110 [============================>.] - ETA: 0s - loss: 0.0051
# Epoch 90: saving model to checkpoints_LSTM_agg_holidays\model_epoch_90.h5
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0051 - val_loss: 0.0057
# Epoch 91/300
# 109/110 [============================>.] - ETA: 0s - loss: 0.0052
# Epoch 91: saving model to checkpoints_LSTM_agg_holidays\model_epoch_91.h5
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0052 - val_loss: 0.0057
# Epoch 92/300
# 109/110 [============================>.] - ETA: 0s - loss: 0.0052
# Epoch 92: saving model to checkpoints_LSTM_agg_holidays\model_epoch_92.h5
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0052 - val_loss: 0.0056
# Epoch 93/300
# 109/110 [============================>.] - ETA: 0s - loss: 0.0050
# Epoch 93: saving model to checkpoints_LSTM_agg_holidays\model_epoch_93.h5
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0050 - val_loss: 0.0057
# Epoch 94/300
# 109/110 [============================>.] - ETA: 0s - loss: 0.0052
# Epoch 94: saving model to checkpoints_LSTM_agg_holidays\model_epoch_94.h5
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0052 - val_loss: 0.0059
# Epoch 95/300
# 109/110 [============================>.] - ETA: 0s - loss: 0.0053
# Epoch 95: saving model to checkpoints_LSTM_agg_holidays\model_epoch_95.h5
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0053 - val_loss: 0.0056
# Epoch 96/300
# 109/110 [============================>.] - ETA: 0s - loss: 0.0051
# Epoch 96: saving model to checkpoints_LSTM_agg_holidays\model_epoch_96.h5
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0051 - val_loss: 0.0057
# Epoch 97/300
# 109/110 [============================>.] - ETA: 0s - loss: 0.0051
# Epoch 97: saving model to checkpoints_LSTM_agg_holidays\model_epoch_97.h5
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0050 - val_loss: 0.0058
# Epoch 98/300
# 109/110 [============================>.] - ETA: 0s - loss: 0.0050
# Epoch 98: saving model to checkpoints_LSTM_agg_holidays\model_epoch_98.h5
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0049 - val_loss: 0.0055
# Epoch 99/300
# 109/110 [============================>.] - ETA: 0s - loss: 0.0051
# Epoch 99: saving model to checkpoints_LSTM_agg_holidays\model_epoch_99.h5
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0051 - val_loss: 0.0061
# Epoch 100/300
# 109/110 [============================>.] - ETA: 0s - loss: 0.0052
# Epoch 100: saving model to checkpoints_LSTM_agg_holidays\model_epoch_100.h5
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0052 - val_loss: 0.0054
# Epoch 101/300
# 109/110 [============================>.] - ETA: 0s - loss: 0.0052
# Epoch 101: saving model to checkpoints_LSTM_agg_holidays\model_epoch_101.h5
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0052 - val_loss: 0.0056
# Epoch 102/300
# 109/110 [============================>.] - ETA: 0s - loss: 0.0050
# Epoch 102: saving model to checkpoints_LSTM_agg_holidays\model_epoch_102.h5
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0050 - val_loss: 0.0058
# Epoch 103/300
# 109/110 [============================>.] - ETA: 0s - loss: 0.0051
# Epoch 103: saving model to checkpoints_LSTM_agg_holidays\model_epoch_103.h5
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0051 - val_loss: 0.0060
# Epoch 104/300
# 109/110 [============================>.] - ETA: 0s - loss: 0.0049
# Epoch 104: saving model to checkpoints_LSTM_agg_holidays\model_epoch_104.h5
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0049 - val_loss: 0.0056
# Epoch 105/300
# 109/110 [============================>.] - ETA: 0s - loss: 0.0049
# Epoch 105: saving model to checkpoints_LSTM_agg_holidays\model_epoch_105.h5
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0049 - val_loss: 0.0057
# Epoch 106/300
# 109/110 [============================>.] - ETA: 0s - loss: 0.0049
# Epoch 106: saving model to checkpoints_LSTM_agg_holidays\model_epoch_106.h5
# 110/110 [==============================] - 1s 10ms/step - loss: 0.0049 - val_loss: 0.0056
# Epoch 107/300
# 109/110 [============================>.] - ETA: 0s - loss: 0.0051
# Epoch 107: saving model to checkpoints_LSTM_agg_holidays\model_epoch_107.h5
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0051 - val_loss: 0.0063
# Epoch 108/300
# 109/110 [============================>.] - ETA: 0s - loss: 0.0050
# Epoch 108: saving model to checkpoints_LSTM_agg_holidays\model_epoch_108.h5
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0050 - val_loss: 0.0055
# Epoch 109/300
# 109/110 [============================>.] - ETA: 0s - loss: 0.0049
# Epoch 109: saving model to checkpoints_LSTM_agg_holidays\model_epoch_109.h5
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0049 - val_loss: 0.0061
# Epoch 110/300
# 109/110 [============================>.] - ETA: 0s - loss: 0.0049
# Epoch 110: saving model to checkpoints_LSTM_agg_holidays\model_epoch_110.h5
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0049 - val_loss: 0.0055
# Epoch 111/300
# 109/110 [============================>.] - ETA: 0s - loss: 0.0049
# Epoch 111: saving model to checkpoints_LSTM_agg_holidays\model_epoch_111.h5
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0049 - val_loss: 0.0057
# Epoch 112/300
# 109/110 [============================>.] - ETA: 0s - loss: 0.0048
# Epoch 112: saving model to checkpoints_LSTM_agg_holidays\model_epoch_112.h5
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0048 - val_loss: 0.0056
# Epoch 113/300
# 109/110 [============================>.] - ETA: 0s - loss: 0.0048
# Epoch 113: saving model to checkpoints_LSTM_agg_holidays\model_epoch_113.h5
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0048 - val_loss: 0.0059
# Epoch 114/300
# 109/110 [============================>.] - ETA: 0s - loss: 0.0048
# Epoch 114: saving model to checkpoints_LSTM_agg_holidays\model_epoch_114.h5
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0047 - val_loss: 0.0058
# Epoch 115/300
# 109/110 [============================>.] - ETA: 0s - loss: 0.0046
# Epoch 115: saving model to checkpoints_LSTM_agg_holidays\model_epoch_115.h5
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0046 - val_loss: 0.0055
# Epoch 116/300
# 109/110 [============================>.] - ETA: 0s - loss: 0.0049
# Epoch 116: saving model to checkpoints_LSTM_agg_holidays\model_epoch_116.h5
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0049 - val_loss: 0.0062
# Epoch 117/300
# 109/110 [============================>.] - ETA: 0s - loss: 0.0049
# Epoch 117: saving model to checkpoints_LSTM_agg_holidays\model_epoch_117.h5
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0049 - val_loss: 0.0055
# Epoch 118/300
# 109/110 [============================>.] - ETA: 0s - loss: 0.0051
# Epoch 118: saving model to checkpoints_LSTM_agg_holidays\model_epoch_118.h5
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0051 - val_loss: 0.0065
# Epoch 119/300
# 109/110 [============================>.] - ETA: 0s - loss: 0.0049
# Epoch 119: saving model to checkpoints_LSTM_agg_holidays\model_epoch_119.h5
# 110/110 [==============================] - 1s 10ms/step - loss: 0.0048 - val_loss: 0.0058
# Epoch 120/300
# 109/110 [============================>.] - ETA: 0s - loss: 0.0047
# Epoch 120: saving model to checkpoints_LSTM_agg_holidays\model_epoch_120.h5
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0047 - val_loss: 0.0056
# Epoch 121/300
# 109/110 [============================>.] - ETA: 0s - loss: 0.0046
# Epoch 121: saving model to checkpoints_LSTM_agg_holidays\model_epoch_121.h5
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0046 - val_loss: 0.0060
# Epoch 122/300
# 108/110 [============================>.] - ETA: 0s - loss: 0.0047
# Epoch 122: saving model to checkpoints_LSTM_agg_holidays\model_epoch_122.h5
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0047 - val_loss: 0.0056
# Epoch 123/300
# 109/110 [============================>.] - ETA: 0s - loss: 0.0045
# Epoch 123: saving model to checkpoints_LSTM_agg_holidays\model_epoch_123.h5
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0045 - val_loss: 0.0060
# Epoch 124/300
# 109/110 [============================>.] - ETA: 0s - loss: 0.0045
# Epoch 124: saving model to checkpoints_LSTM_agg_holidays\model_epoch_124.h5
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0045 - val_loss: 0.0062
# Epoch 125/300
# 109/110 [============================>.] - ETA: 0s - loss: 0.0045
# Epoch 125: saving model to checkpoints_LSTM_agg_holidays\model_epoch_125.h5
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0045 - val_loss: 0.0057
# Epoch 126/300
# 109/110 [============================>.] - ETA: 0s - loss: 0.0046
# Epoch 126: saving model to checkpoints_LSTM_agg_holidays\model_epoch_126.h5
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0046 - val_loss: 0.0069
# Epoch 127/300
# 109/110 [============================>.] - ETA: 0s - loss: 0.0047
# Epoch 127: saving model to checkpoints_LSTM_agg_holidays\model_epoch_127.h5
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0047 - val_loss: 0.0056
# Epoch 128/300
# 109/110 [============================>.] - ETA: 0s - loss: 0.0044
# Epoch 128: saving model to checkpoints_LSTM_agg_holidays\model_epoch_128.h5
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0044 - val_loss: 0.0057
# Epoch 129/300
# 109/110 [============================>.] - ETA: 0s - loss: 0.0043
# Epoch 129: saving model to checkpoints_LSTM_agg_holidays\model_epoch_129.h5
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0043 - val_loss: 0.0058
# Epoch 130/300
# 109/110 [============================>.] - ETA: 0s - loss: 0.0043
# Epoch 130: saving model to checkpoints_LSTM_agg_holidays\model_epoch_130.h5
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0043 - val_loss: 0.0060
# Epoch 131/300
# 109/110 [============================>.] - ETA: 0s - loss: 0.0044
# Epoch 131: saving model to checkpoints_LSTM_agg_holidays\model_epoch_131.h5
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0044 - val_loss: 0.0066
# Epoch 132/300
# 109/110 [============================>.] - ETA: 0s - loss: 0.0045
# Epoch 132: saving model to checkpoints_LSTM_agg_holidays\model_epoch_132.h5
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0044 - val_loss: 0.0058
# Epoch 133/300
# 109/110 [============================>.] - ETA: 0s - loss: 0.0042
# Epoch 133: saving model to checkpoints_LSTM_agg_holidays\model_epoch_133.h5
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0042 - val_loss: 0.0061
# Epoch 134/300
# 109/110 [============================>.] - ETA: 0s - loss: 0.0042
# Epoch 134: saving model to checkpoints_LSTM_agg_holidays\model_epoch_134.h5
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0042 - val_loss: 0.0062
# Epoch 135/300
# 109/110 [============================>.] - ETA: 0s - loss: 0.0041
# Epoch 135: saving model to checkpoints_LSTM_agg_holidays\model_epoch_135.h5
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0041 - val_loss: 0.0062
# Epoch 136/300
# 109/110 [============================>.] - ETA: 0s - loss: 0.0043
# Epoch 136: saving model to checkpoints_LSTM_agg_holidays\model_epoch_136.h5
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0043 - val_loss: 0.0072
# Epoch 137/300
# 109/110 [============================>.] - ETA: 0s - loss: 0.0046
# Epoch 137: saving model to checkpoints_LSTM_agg_holidays\model_epoch_137.h5
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0046 - val_loss: 0.0060
# Epoch 138/300
# 109/110 [============================>.] - ETA: 0s - loss: 0.0046
# Epoch 138: saving model to checkpoints_LSTM_agg_holidays\model_epoch_138.h5
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0046 - val_loss: 0.0060
# Epoch 139/300
# 109/110 [============================>.] - ETA: 0s - loss: 0.0043
# Epoch 139: saving model to checkpoints_LSTM_agg_holidays\model_epoch_139.h5
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0043 - val_loss: 0.0065
# Epoch 140/300
# 109/110 [============================>.] - ETA: 0s - loss: 0.0043
# Epoch 140: saving model to checkpoints_LSTM_agg_holidays\model_epoch_140.h5
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0043 - val_loss: 0.0064
# Epoch 141/300
# 109/110 [============================>.] - ETA: 0s - loss: 0.0040
# Epoch 141: saving model to checkpoints_LSTM_agg_holidays\model_epoch_141.h5
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0040 - val_loss: 0.0063
# Epoch 142/300
# 109/110 [============================>.] - ETA: 0s - loss: 0.0039
# Epoch 142: saving model to checkpoints_LSTM_agg_holidays\model_epoch_142.h5
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0039 - val_loss: 0.0061
# Epoch 143/300
# 109/110 [============================>.] - ETA: 0s - loss: 0.0040
# Epoch 143: saving model to checkpoints_LSTM_agg_holidays\model_epoch_143.h5
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0040 - val_loss: 0.0071
# Epoch 144/300
# 109/110 [============================>.] - ETA: 0s - loss: 0.0041
# Epoch 144: saving model to checkpoints_LSTM_agg_holidays\model_epoch_144.h5
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0041 - val_loss: 0.0063
# Epoch 145/300
# 109/110 [============================>.] - ETA: 0s - loss: 0.0040
# Epoch 145: saving model to checkpoints_LSTM_agg_holidays\model_epoch_145.h5
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0039 - val_loss: 0.0065
# Epoch 146/300
# 109/110 [============================>.] - ETA: 0s - loss: 0.0039
# Epoch 146: saving model to checkpoints_LSTM_agg_holidays\model_epoch_146.h5
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0039 - val_loss: 0.0063
# Epoch 147/300
# 109/110 [============================>.] - ETA: 0s - loss: 0.0039
# Epoch 147: saving model to checkpoints_LSTM_agg_holidays\model_epoch_147.h5
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0039 - val_loss: 0.0064
# Epoch 148/300
# 109/110 [============================>.] - ETA: 0s - loss: 0.0040
# Epoch 148: saving model to checkpoints_LSTM_agg_holidays\model_epoch_148.h5
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0040 - val_loss: 0.0065
# Epoch 149/300
# 109/110 [============================>.] - ETA: 0s - loss: 0.0038
# Epoch 149: saving model to checkpoints_LSTM_agg_holidays\model_epoch_149.h5
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0038 - val_loss: 0.0067
# Epoch 150/300
# 109/110 [============================>.] - ETA: 0s - loss: 0.0039
# Epoch 150: saving model to checkpoints_LSTM_agg_holidays\model_epoch_150.h5
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0039 - val_loss: 0.0069

# %%
#plot the training and validation loss for each iteration for the LSTM model
plt.figure(figsize=(12, 6), dpi=200)

plt.plot(history.history['loss'], label='Training loss')
plt.plot(history.history['val_loss'], label='Validation loss')
plt.legend()
plt.title('Training and iteration loss through iterations')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
#determine the best model according to the validation loss
min_val_loss = min(history.history['val_loss'])
min_val_loss_epoch = np.argmin(history.history['val_loss']) + 1
print(f"Min validation loss of {min_val_loss} reached at epoch {min_val_loss_epoch}")
# Out:
# Minimum validation loss of 0.005417324136942625 reached at epoch 100

# %%
#load the model
model = load_model('checkpoints_LSTM_daily/model_epoch_100.h5')

# %%
#predict and calculate test RMSE
pred = model.predict(x_test)
score = np.sqrt(metrics.mean_squared_error(pred,y_test))
print("Score (RMSE): {}".format(score))
# Out:
# 2/2 [==============================] - 1s 172ms/step
# Score (RMSE): 0.0701032186523979

# %%
#upload test predictions to the database
pred = scaler.inverse_transform(pred)
data = [(float(element), i+1) for i, element in enumerate(pred)]
query = "UPDATE rq3_test_predictions_daily SET lstm_nn = %s WHERE id = %s"
cursor.executemany(query, data)
db_connection.commit()

# %% [markdown]
# ### Hourly data

# %%
query = '''
SELECT
    DATE_FORMAT(u.date_time, '%Y-%m-%d %H:00:00') as hour, 
    COUNT(*) as count,
    MAX(t.boxing_day) as boxing_day,
    MAX(t.boxing_day_obs) as boxing_day_obs,
    MAX(t.christmas_day) as christmas_day,
    MAX(t.christmas_day_obs) as christmas_day_obs,
    MAX(t.good_friday) as good_friday,
    MAX(t.may_day) as may_day,
    MAX(t.new_years_day) as new_years_day,
    MAX(t.new_years_day_obs) as new_years_day_obs,
    MAX(t.platinum_jubilee) as platinum_jubilee,
    MAX(t.spring_bank_holiday) as spring_bank_holiday,
    MAX(t.state_funeral) as state_funeral,
    MAX(t.outlier) as outlier
FROM use_of_force u
LEFT JOIN rq3_add_variables t 
  ON DATE_FORMAT(u.date_time, '%Y-%m-%d 00:00:00') = t.date
WHERE u.date_time > '2019-01-01 00:00:00' AND u.PrimaryConduct > 0
GROUP BY DATE_FORMAT(u.date_time, '%Y-%m-%d %H:00:00');
'''
time_series_daily = pd.read_sql(query, db_connection)

time_series_daily['hour'] = pd.to_datetime(time_series_daily['hour'])
time_series_daily.set_index('hour', inplace=True)
time_series_daily = time_series_daily.resample('H').sum()
time_series_daily = time_series_daily.reset_index()

scaler = MinMaxScaler()
time_series_daily['count'] = scaler.fit_transform(time_series_daily[['count']])

time_series_daily['hour'] = pd.to_datetime(time_series_daily['hour'])
time_series_daily = time_series_daily.set_index('hour')  
df = time_series_daily[['count', 'boxing_day', 'boxing_day_obs', 'christmas_day',
       'christmas_day_obs', 'good_friday', 'may_day', 'new_years_day',
       'new_years_day_obs', 'platinum_jubilee', 'spring_bank_holiday',
       'state_funeral', 'outlier']].values
# Out:
# C:\Users\Nikita\AppData\Local\Temp/ipykernel_16808/1564691695.py:23: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   time_series_daily = pd.read_sql(query, db_connection)

# %%
sequence_size = 30*24
x, y = to_sequences(sequence_size, df)

train_test_split_index = len(x) - 24*7
x_train = x[:train_test_split_index]
y_train = y[:train_test_split_index]
x_test = x[train_test_split_index:]
y_test = y[train_test_split_index:]
print("Shape of training set: {}".format(x_train.shape))
print("Shape of test set: {}".format(x_test.shape))
# Out:
# Shape of training set: (27574, 720, 13)
# Shape of test set: (168, 720, 13)

# %%
model = Sequential()
model.add(InputLayer((x_test.shape[1], x_test.shape[2]))) 
model.add(LSTM(500, activation='tanh', return_sequences=True))
model.add(Dropout(0.1))
model.add(LSTM(500, activation='tanh'))
model.add(Dense(128, 'relu'))
model.add(Dense(64, 'relu'))
model.add(Dense(1, 'linear'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 720, 500)          1028000
#
#  dropout (Dropout)           (None, 720, 500)          0
#
#  lstm_1 (LSTM)               (None, 500)               2002000
#
#  dense (Dense)               (None, 128)               64128
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dense_2 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 3,102,449
# Trainable params: 3,102,449
# Non-trainable params: 0
# _________________________________________________________________

# %%
os.makedirs("checkpoints_LSTM_agg_holidays_hourly", exist_ok=True)
model_checkpoint = ModelCheckpoint('checkpoints_LSTM_agg_holidays_hourly/model_epoch_{epoch:02d}.h5', 
                                   monitor='val_loss', verbose=1, save_best_only=False, mode='min')
early_stop = keras.callbacks.EarlyStopping(patience=50, restore_best_weights=True)
model.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.0001))
history = model.fit(x_train, y_train, validation_split=0.1, shuffle=False, epochs=100, 
                     batch_size=128, callbacks=[model_checkpoint, early_stop])
# Out:
# Epoch 1/100
# 194/194 [==============================] - ETA: 0s - loss: 0.0069
# Epoch 1: saving model to checkpoints_LSTM_agg_holidays_hourly\model_epoch_01.h5
# 194/194 [==============================] - 82s 401ms/step - loss: 0.0069 - val_loss: 0.0043
# Epoch 2/100
# 194/194 [==============================] - ETA: 0s - loss: 0.0048
# Epoch 2: saving model to checkpoints_LSTM_agg_holidays_hourly\model_epoch_02.h5
# 194/194 [==============================] - 78s 402ms/step - loss: 0.0048 - val_loss: 0.0042
# Epoch 3/100
# 194/194 [==============================] - ETA: 0s - loss: 0.0047
# Epoch 3: saving model to checkpoints_LSTM_agg_holidays_hourly\model_epoch_03.h5
# 194/194 [==============================] - 78s 403ms/step - loss: 0.0047 - val_loss: 0.0042
# Epoch 4/100
# 194/194 [==============================] - ETA: 0s - loss: 0.0046
# Epoch 4: saving model to checkpoints_LSTM_agg_holidays_hourly\model_epoch_04.h5
# 194/194 [==============================] - 78s 404ms/step - loss: 0.0046 - val_loss: 0.0041
# Epoch 5/100
# 194/194 [==============================] - ETA: 0s - loss: 0.0045
# Epoch 5: saving model to checkpoints_LSTM_agg_holidays_hourly\model_epoch_05.h5
# 194/194 [==============================] - 78s 404ms/step - loss: 0.0045 - val_loss: 0.0041
# Epoch 6/100
# 194/194 [==============================] - ETA: 0s - loss: 0.0045
# Epoch 6: saving model to checkpoints_LSTM_agg_holidays_hourly\model_epoch_06.h5
# 194/194 [==============================] - 78s 404ms/step - loss: 0.0045 - val_loss: 0.0040
# Epoch 7/100
# 194/194 [==============================] - ETA: 0s - loss: 0.0045
# Epoch 7: saving model to checkpoints_LSTM_agg_holidays_hourly\model_epoch_07.h5
# 194/194 [==============================] - 79s 405ms/step - loss: 0.0045 - val_loss: 0.0040
# Epoch 8/100
# 194/194 [==============================] - ETA: 0s - loss: 0.0045
# Epoch 8: saving model to checkpoints_LSTM_agg_holidays_hourly\model_epoch_08.h5
# 194/194 [==============================] - 79s 405ms/step - loss: 0.0045 - val_loss: 0.0040
# Epoch 9/100
# 194/194 [==============================] - ETA: 0s - loss: 0.0044
# Epoch 9: saving model to checkpoints_LSTM_agg_holidays_hourly\model_epoch_09.h5
# 194/194 [==============================] - 79s 405ms/step - loss: 0.0044 - val_loss: 0.0040
# Epoch 10/100
# 194/194 [==============================] - ETA: 0s - loss: 0.0044
# Epoch 10: saving model to checkpoints_LSTM_agg_holidays_hourly\model_epoch_10.h5
# 194/194 [==============================] - 79s 405ms/step - loss: 0.0044 - val_loss: 0.0040
# Epoch 11/100
# 194/194 [==============================] - ETA: 0s - loss: 0.0044
# Epoch 11: saving model to checkpoints_LSTM_agg_holidays_hourly\model_epoch_11.h5
# 194/194 [==============================] - 79s 405ms/step - loss: 0.0044 - val_loss: 0.0040
# Epoch 12/100
# 194/194 [==============================] - ETA: 0s - loss: 0.0044
# Epoch 12: saving model to checkpoints_LSTM_agg_holidays_hourly\model_epoch_12.h5
# 194/194 [==============================] - 79s 405ms/step - loss: 0.0044 - val_loss: 0.0040
# Epoch 13/100
# 194/194 [==============================] - ETA: 0s - loss: 0.0043
# Epoch 13: saving model to checkpoints_LSTM_agg_holidays_hourly\model_epoch_13.h5
# 194/194 [==============================] - 79s 405ms/step - loss: 0.0043 - val_loss: 0.0038
# Epoch 14/100
# 194/194 [==============================] - ETA: 0s - loss: 0.0043
# Epoch 14: saving model to checkpoints_LSTM_agg_holidays_hourly\model_epoch_14.h5
# 194/194 [==============================] - 79s 405ms/step - loss: 0.0043 - val_loss: 0.0040
# Epoch 15/100
# 194/194 [==============================] - ETA: 0s - loss: 0.0043
# Epoch 15: saving model to checkpoints_LSTM_agg_holidays_hourly\model_epoch_15.h5
# 194/194 [==============================] - 79s 405ms/step - loss: 0.0043 - val_loss: 0.0038
# Epoch 16/100
# 194/194 [==============================] - ETA: 0s - loss: 0.0043
# Epoch 16: saving model to checkpoints_LSTM_agg_holidays_hourly\model_epoch_16.h5
# 194/194 [==============================] - 79s 405ms/step - loss: 0.0043 - val_loss: 0.0038
# Epoch 17/100
# 194/194 [==============================] - ETA: 0s - loss: 0.0043
# Epoch 17: saving model to checkpoints_LSTM_agg_holidays_hourly\model_epoch_17.h5
# 194/194 [==============================] - 79s 405ms/step - loss: 0.0043 - val_loss: 0.0039
# Epoch 18/100
# 194/194 [==============================] - ETA: 0s - loss: 0.0043
# Epoch 18: saving model to checkpoints_LSTM_agg_holidays_hourly\model_epoch_18.h5
# 194/194 [==============================] - 79s 405ms/step - loss: 0.0043 - val_loss: 0.0039
# Epoch 19/100
# 194/194 [==============================] - ETA: 0s - loss: 0.0043
# Epoch 19: saving model to checkpoints_LSTM_agg_holidays_hourly\model_epoch_19.h5
# 194/194 [==============================] - 79s 405ms/step - loss: 0.0043 - val_loss: 0.0038
# Epoch 20/100
# 194/194 [==============================] - ETA: 0s - loss: 0.0043
# Epoch 20: saving model to checkpoints_LSTM_agg_holidays_hourly\model_epoch_20.h5
# 194/194 [==============================] - 79s 405ms/step - loss: 0.0043 - val_loss: 0.0039
# Epoch 21/100
# 194/194 [==============================] - ETA: 0s - loss: 0.0042
# Epoch 21: saving model to checkpoints_LSTM_agg_holidays_hourly\model_epoch_21.h5
# 194/194 [==============================] - 79s 405ms/step - loss: 0.0042 - val_loss: 0.0039
# Epoch 22/100
# 194/194 [==============================] - ETA: 0s - loss: 0.0042
# Epoch 22: saving model to checkpoints_LSTM_agg_holidays_hourly\model_epoch_22.h5
# 194/194 [==============================] - 79s 405ms/step - loss: 0.0042 - val_loss: 0.0039
# Epoch 23/100
# 194/194 [==============================] - ETA: 0s - loss: 0.0042
# Epoch 23: saving model to checkpoints_LSTM_agg_holidays_hourly\model_epoch_23.h5
# 194/194 [==============================] - 79s 405ms/step - loss: 0.0042 - val_loss: 0.0037
# Epoch 24/100
# 194/194 [==============================] - ETA: 0s - loss: 0.0042
# Epoch 24: saving model to checkpoints_LSTM_agg_holidays_hourly\model_epoch_24.h5
# 194/194 [==============================] - 79s 405ms/step - loss: 0.0042 - val_loss: 0.0038
# Epoch 25/100
# 194/194 [==============================] - ETA: 0s - loss: 0.0042
# Epoch 25: saving model to checkpoints_LSTM_agg_holidays_hourly\model_epoch_25.h5
# 194/194 [==============================] - 79s 406ms/step - loss: 0.0042 - val_loss: 0.0037
# Epoch 26/100
# 194/194 [==============================] - ETA: 0s - loss: 0.0042
# Epoch 26: saving model to checkpoints_LSTM_agg_holidays_hourly\model_epoch_26.h5
# 194/194 [==============================] - 79s 406ms/step - loss: 0.0042 - val_loss: 0.0038
# Epoch 27/100
# 194/194 [==============================] - ETA: 0s - loss: 0.0042
# Epoch 27: saving model to checkpoints_LSTM_agg_holidays_hourly\model_epoch_27.h5
# 194/194 [==============================] - 79s 405ms/step - loss: 0.0042 - val_loss: 0.0038
# Epoch 28/100
# 194/194 [==============================] - ETA: 0s - loss: 0.0042
# Epoch 28: saving model to checkpoints_LSTM_agg_holidays_hourly\model_epoch_28.h5
# 194/194 [==============================] - 79s 405ms/step - loss: 0.0042 - val_loss: 0.0038
# Epoch 29/100
# 194/194 [==============================] - ETA: 0s - loss: 0.0042
# Epoch 29: saving model to checkpoints_LSTM_agg_holidays_hourly\model_epoch_29.h5
# 194/194 [==============================] - 79s 405ms/step - loss: 0.0042 - val_loss: 0.0038
# Epoch 30/100
# 194/194 [==============================] - ETA: 0s - loss: 0.0042
# Epoch 30: saving model to checkpoints_LSTM_agg_holidays_hourly\model_epoch_30.h5
# 194/194 [==============================] - 79s 405ms/step - loss: 0.0042 - val_loss: 0.0038
# Epoch 31/100
# 194/194 [==============================] - ETA: 0s - loss: 0.0042
# Epoch 31: saving model to checkpoints_LSTM_agg_holidays_hourly\model_epoch_31.h5
# 194/194 [==============================] - 79s 405ms/step - loss: 0.0042 - val_loss: 0.0038
# Epoch 32/100
# 194/194 [==============================] - ETA: 0s - loss: 0.0042
# Epoch 32: saving model to checkpoints_LSTM_agg_holidays_hourly\model_epoch_32.h5
# 194/194 [==============================] - 79s 405ms/step - loss: 0.0042 - val_loss: 0.0039
# Epoch 33/100
# 194/194 [==============================] - ETA: 0s - loss: 0.0042
# Epoch 33: saving model to checkpoints_LSTM_agg_holidays_hourly\model_epoch_33.h5
# 194/194 [==============================] - 79s 405ms/step - loss: 0.0042 - val_loss: 0.0038
# Epoch 34/100
# 194/194 [==============================] - ETA: 0s - loss: 0.0042
# Epoch 34: saving model to checkpoints_LSTM_agg_holidays_hourly\model_epoch_34.h5
# 194/194 [==============================] - 79s 405ms/step - loss: 0.0042 - val_loss: 0.0038
# Epoch 35/100
# 194/194 [==============================] - ETA: 0s - loss: 0.0042
# Epoch 35: saving model to checkpoints_LSTM_agg_holidays_hourly\model_epoch_35.h5
# 194/194 [==============================] - 79s 405ms/step - loss: 0.0042 - val_loss: 0.0038
# Epoch 36/100
# 194/194 [==============================] - ETA: 0s - loss: 0.0042
# Epoch 36: saving model to checkpoints_LSTM_agg_holidays_hourly\model_epoch_36.h5
# 194/194 [==============================] - 79s 406ms/step - loss: 0.0042 - val_loss: 0.0039
# Epoch 37/100
# 194/194 [==============================] - ETA: 0s - loss: 0.0042
# Epoch 37: saving model to checkpoints_LSTM_agg_holidays_hourly\model_epoch_37.h5
# 194/194 [==============================] - 79s 406ms/step - loss: 0.0042 - val_loss: 0.0038
# Epoch 38/100
# 194/194 [==============================] - ETA: 0s - loss: 0.0041
# Epoch 38: saving model to checkpoints_LSTM_agg_holidays_hourly\model_epoch_38.h5
# 194/194 [==============================] - 79s 405ms/step - loss: 0.0041 - val_loss: 0.0038
# Epoch 39/100
# 194/194 [==============================] - ETA: 0s - loss: 0.0041
# Epoch 39: saving model to checkpoints_LSTM_agg_holidays_hourly\model_epoch_39.h5
# 194/194 [==============================] - 79s 405ms/step - loss: 0.0041 - val_loss: 0.0039
# Epoch 40/100
# 194/194 [==============================] - ETA: 0s - loss: 0.0041
# Epoch 40: saving model to checkpoints_LSTM_agg_holidays_hourly\model_epoch_40.h5
# 194/194 [==============================] - 79s 405ms/step - loss: 0.0041 - val_loss: 0.0039
# Epoch 41/100
# 194/194 [==============================] - ETA: 0s - loss: 0.0041
# Epoch 41: saving model to checkpoints_LSTM_agg_holidays_hourly\model_epoch_41.h5
# 194/194 [==============================] - 79s 405ms/step - loss: 0.0041 - val_loss: 0.0040
# Epoch 42/100
# 194/194 [==============================] - ETA: 0s - loss: 0.0041
# Epoch 42: saving model to checkpoints_LSTM_agg_holidays_hourly\model_epoch_42.h5
# 194/194 [==============================] - 79s 405ms/step - loss: 0.0041 - val_loss: 0.0039
# Epoch 43/100
# 194/194 [==============================] - ETA: 0s - loss: 0.0041
# Epoch 43: saving model to checkpoints_LSTM_agg_holidays_hourly\model_epoch_43.h5
# 194/194 [==============================] - 79s 405ms/step - loss: 0.0041 - val_loss: 0.0039
# Epoch 44/100
# 194/194 [==============================] - ETA: 0s - loss: 0.0041
# Epoch 44: saving model to checkpoints_LSTM_agg_holidays_hourly\model_epoch_44.h5
# 194/194 [==============================] - 79s 406ms/step - loss: 0.0041 - val_loss: 0.0039
# Epoch 45/100
# 194/194 [==============================] - ETA: 0s - loss: 0.0041
# Epoch 45: saving model to checkpoints_LSTM_agg_holidays_hourly\model_epoch_45.h5
# 194/194 [==============================] - 79s 405ms/step - loss: 0.0041 - val_loss: 0.0038
# Epoch 46/100
# 194/194 [==============================] - ETA: 0s - loss: 0.0041
# Epoch 46: saving model to checkpoints_LSTM_agg_holidays_hourly\model_epoch_46.h5
# 194/194 [==============================] - 79s 406ms/step - loss: 0.0041 - val_loss: 0.0039
# Epoch 47/100
# 194/194 [==============================] - ETA: 0s - loss: 0.0041
# Epoch 47: saving model to checkpoints_LSTM_agg_holidays_hourly\model_epoch_47.h5
# 194/194 [==============================] - 79s 406ms/step - loss: 0.0041 - val_loss: 0.0039
# Epoch 48/100
# 194/194 [==============================] - ETA: 0s - loss: 0.0041
# Epoch 48: saving model to checkpoints_LSTM_agg_holidays_hourly\model_epoch_48.h5
# 194/194 [==============================] - 79s 405ms/step - loss: 0.0041 - val_loss: 0.0039
# Epoch 49/100
# 194/194 [==============================] - ETA: 0s - loss: 0.0041
# Epoch 49: saving model to checkpoints_LSTM_agg_holidays_hourly\model_epoch_49.h5
# 194/194 [==============================] - 79s 405ms/step - loss: 0.0041 - val_loss: 0.0039
# Epoch 50/100
# 194/194 [==============================] - ETA: 0s - loss: 0.0041
# Epoch 50: saving model to checkpoints_LSTM_agg_holidays_hourly\model_epoch_50.h5
# 194/194 [==============================] - 79s 406ms/step - loss: 0.0041 - val_loss: 0.0038
# Epoch 51/100
# 194/194 [==============================] - ETA: 0s - loss: 0.0041
# Epoch 51: saving model to checkpoints_LSTM_agg_holidays_hourly\model_epoch_51.h5
# 194/194 [==============================] - 79s 405ms/step - loss: 0.0041 - val_loss: 0.0040
# Epoch 52/100
# 194/194 [==============================] - ETA: 0s - loss: 0.0041
# Epoch 52: saving model to checkpoints_LSTM_agg_holidays_hourly\model_epoch_52.h5
# 194/194 [==============================] - 79s 405ms/step - loss: 0.0041 - val_loss: 0.0038
# Epoch 53/100
# 194/194 [==============================] - ETA: 0s - loss: 0.0041
# Epoch 53: saving model to checkpoints_LSTM_agg_holidays_hourly\model_epoch_53.h5
# 194/194 [==============================] - 79s 406ms/step - loss: 0.0041 - val_loss: 0.0038
# Epoch 54/100
# 194/194 [==============================] - ETA: 0s - loss: 0.0041
# Epoch 54: saving model to checkpoints_LSTM_agg_holidays_hourly\model_epoch_54.h5
# 194/194 [==============================] - 79s 405ms/step - loss: 0.0041 - val_loss: 0.0038
# Epoch 55/100
# 194/194 [==============================] - ETA: 0s - loss: 0.0041
# Epoch 55: saving model to checkpoints_LSTM_agg_holidays_hourly\model_epoch_55.h5
# 194/194 [==============================] - 79s 406ms/step - loss: 0.0041 - val_loss: 0.0039
# Epoch 56/100
# 194/194 [==============================] - ETA: 0s - loss: 0.0041
# Epoch 56: saving model to checkpoints_LSTM_agg_holidays_hourly\model_epoch_56.h5
# 194/194 [==============================] - 79s 406ms/step - loss: 0.0041 - val_loss: 0.0039
# Epoch 57/100
# 194/194 [==============================] - ETA: 0s - loss: 0.0041
# Epoch 57: saving model to checkpoints_LSTM_agg_holidays_hourly\model_epoch_57.h5
# 194/194 [==============================] - 79s 405ms/step - loss: 0.0041 - val_loss: 0.0038
# Epoch 58/100
# 194/194 [==============================] - ETA: 0s - loss: 0.0041
# Epoch 58: saving model to checkpoints_LSTM_agg_holidays_hourly\model_epoch_58.h5
# 194/194 [==============================] - 79s 406ms/step - loss: 0.0041 - val_loss: 0.0039
# Epoch 59/100
# 194/194 [==============================] - ETA: 0s - loss: 0.0041
# Epoch 59: saving model to checkpoints_LSTM_agg_holidays_hourly\model_epoch_59.h5
# 194/194 [==============================] - 79s 406ms/step - loss: 0.0041 - val_loss: 0.0040
# Epoch 60/100
# 194/194 [==============================] - ETA: 0s - loss: 0.0041
# Epoch 60: saving model to checkpoints_LSTM_agg_holidays_hourly\model_epoch_60.h5
# 194/194 [==============================] - 79s 405ms/step - loss: 0.0041 - val_loss: 0.0038
# Epoch 61/100
# 194/194 [==============================] - ETA: 0s - loss: 0.0040
# Epoch 61: saving model to checkpoints_LSTM_agg_holidays_hourly\model_epoch_61.h5
# 194/194 [==============================] - 79s 406ms/step - loss: 0.0040 - val_loss: 0.0039
# Epoch 62/100
# 194/194 [==============================] - ETA: 0s - loss: 0.0040
# Epoch 62: saving model to checkpoints_LSTM_agg_holidays_hourly\model_epoch_62.h5
# 194/194 [==============================] - 79s 405ms/step - loss: 0.0040 - val_loss: 0.0038
# Epoch 63/100
# 194/194 [==============================] - ETA: 0s - loss: 0.0040
# Epoch 63: saving model to checkpoints_LSTM_agg_holidays_hourly\model_epoch_63.h5
# 194/194 [==============================] - 79s 405ms/step - loss: 0.0040 - val_loss: 0.0037
# Epoch 64/100
# 194/194 [==============================] - ETA: 0s - loss: 0.0040
# Epoch 64: saving model to checkpoints_LSTM_agg_holidays_hourly\model_epoch_64.h5
# 194/194 [==============================] - 79s 405ms/step - loss: 0.0040 - val_loss: 0.0039
# Epoch 65/100
# 194/194 [==============================] - ETA: 0s - loss: 0.0040
# Epoch 65: saving model to checkpoints_LSTM_agg_holidays_hourly\model_epoch_65.h5
# 194/194 [==============================] - 79s 406ms/step - loss: 0.0040 - val_loss: 0.0039
# Epoch 66/100
# 194/194 [==============================] - ETA: 0s - loss: 0.0040
# Epoch 66: saving model to checkpoints_LSTM_agg_holidays_hourly\model_epoch_66.h5
# 194/194 [==============================] - 79s 405ms/step - loss: 0.0040 - val_loss: 0.0038
# Epoch 67/100
# 194/194 [==============================] - ETA: 0s - loss: 0.0040
# Epoch 67: saving model to checkpoints_LSTM_agg_holidays_hourly\model_epoch_67.h5
# 194/194 [==============================] - 79s 406ms/step - loss: 0.0040 - val_loss: 0.0038
# Epoch 68/100
# 194/194 [==============================] - ETA: 0s - loss: 0.0040
# Epoch 68: saving model to checkpoints_LSTM_agg_holidays_hourly\model_epoch_68.h5
# 194/194 [==============================] - 79s 406ms/step - loss: 0.0040 - val_loss: 0.0037
# Epoch 69/100
# 194/194 [==============================] - ETA: 0s - loss: 0.0040
# Epoch 69: saving model to checkpoints_LSTM_agg_holidays_hourly\model_epoch_69.h5
# 194/194 [==============================] - 79s 406ms/step - loss: 0.0040 - val_loss: 0.0038
# Epoch 70/100
# 194/194 [==============================] - ETA: 0s - loss: 0.0040
# Epoch 70: saving model to checkpoints_LSTM_agg_holidays_hourly\model_epoch_70.h5
# 194/194 [==============================] - 79s 406ms/step - loss: 0.0040 - val_loss: 0.0039
# Epoch 71/100
# 194/194 [==============================] - ETA: 0s - loss: 0.0040
# Epoch 71: saving model to checkpoints_LSTM_agg_holidays_hourly\model_epoch_71.h5
# 194/194 [==============================] - 79s 406ms/step - loss: 0.0040 - val_loss: 0.0037
# Epoch 72/100
# 194/194 [==============================] - ETA: 0s - loss: 0.0040
# Epoch 72: saving model to checkpoints_LSTM_agg_holidays_hourly\model_epoch_72.h5
# 194/194 [==============================] - 79s 406ms/step - loss: 0.0040 - val_loss: 0.0037
# Epoch 73/100
# 194/194 [==============================] - ETA: 0s - loss: 0.0040
# Epoch 73: saving model to checkpoints_LSTM_agg_holidays_hourly\model_epoch_73.h5
# 194/194 [==============================] - 79s 406ms/step - loss: 0.0040 - val_loss: 0.0038
# Epoch 74/100
# 194/194 [==============================] - ETA: 0s - loss: 0.0040
# Epoch 74: saving model to checkpoints_LSTM_agg_holidays_hourly\model_epoch_74.h5
# 194/194 [==============================] - 79s 405ms/step - loss: 0.0040 - val_loss: 0.0037
# Epoch 75/100
# 194/194 [==============================] - ETA: 0s - loss: 0.0040
# Epoch 75: saving model to checkpoints_LSTM_agg_holidays_hourly\model_epoch_75.h5
# 194/194 [==============================] - 79s 406ms/step - loss: 0.0040 - val_loss: 0.0037
# Epoch 76/100
# 194/194 [==============================] - ETA: 0s - loss: 0.0040
# Epoch 76: saving model to checkpoints_LSTM_agg_holidays_hourly\model_epoch_76.h5
# 194/194 [==============================] - 79s 405ms/step - loss: 0.0040 - val_loss: 0.0037
# Epoch 77/100
# 194/194 [==============================] - ETA: 0s - loss: 0.0040
# Epoch 77: saving model to checkpoints_LSTM_agg_holidays_hourly\model_epoch_77.h5
# 194/194 [==============================] - 79s 406ms/step - loss: 0.0040 - val_loss: 0.0039
# Epoch 78/100
# 194/194 [==============================] - ETA: 0s - loss: 0.0040
# Epoch 78: saving model to checkpoints_LSTM_agg_holidays_hourly\model_epoch_78.h5
# 194/194 [==============================] - 79s 405ms/step - loss: 0.0040 - val_loss: 0.0039
# Epoch 79/100
# 194/194 [==============================] - ETA: 0s - loss: 0.0040
# Epoch 79: saving model to checkpoints_LSTM_agg_holidays_hourly\model_epoch_79.h5
# 194/194 [==============================] - 79s 406ms/step - loss: 0.0040 - val_loss: 0.0037
# Epoch 80/100
# 194/194 [==============================] - ETA: 0s - loss: 0.0040
# Epoch 80: saving model to checkpoints_LSTM_agg_holidays_hourly\model_epoch_80.h5
# 194/194 [==============================] - 79s 406ms/step - loss: 0.0040 - val_loss: 0.0036
# Epoch 81/100
# 194/194 [==============================] - ETA: 0s - loss: 0.0040
# Epoch 81: saving model to checkpoints_LSTM_agg_holidays_hourly\model_epoch_81.h5
# 194/194 [==============================] - 79s 406ms/step - loss: 0.0040 - val_loss: 0.0037
# Epoch 82/100
# 194/194 [==============================] - ETA: 0s - loss: 0.0040
# Epoch 82: saving model to checkpoints_LSTM_agg_holidays_hourly\model_epoch_82.h5
# 194/194 [==============================] - 79s 405ms/step - loss: 0.0040 - val_loss: 0.0039
# Epoch 83/100
# 194/194 [==============================] - ETA: 0s - loss: 0.0040
# Epoch 83: saving model to checkpoints_LSTM_agg_holidays_hourly\model_epoch_83.h5
# 194/194 [==============================] - 79s 406ms/step - loss: 0.0040 - val_loss: 0.0036
# Epoch 84/100
# 194/194 [==============================] - ETA: 0s - loss: 0.0040
# Epoch 84: saving model to checkpoints_LSTM_agg_holidays_hourly\model_epoch_84.h5
# 194/194 [==============================] - 79s 406ms/step - loss: 0.0040 - val_loss: 0.0037
# Epoch 85/100
# 194/194 [==============================] - ETA: 0s - loss: 0.0040
# Epoch 85: saving model to checkpoints_LSTM_agg_holidays_hourly\model_epoch_85.h5
# 194/194 [==============================] - 79s 405ms/step - loss: 0.0040 - val_loss: 0.0037
# Epoch 86/100
# 194/194 [==============================] - ETA: 0s - loss: 0.0040
# Epoch 86: saving model to checkpoints_LSTM_agg_holidays_hourly\model_epoch_86.h5
# 194/194 [==============================] - 79s 405ms/step - loss: 0.0040 - val_loss: 0.0038
# Epoch 87/100
# 194/194 [==============================] - ETA: 0s - loss: 0.0040
# Epoch 87: saving model to checkpoints_LSTM_agg_holidays_hourly\model_epoch_87.h5
# 194/194 [==============================] - 79s 406ms/step - loss: 0.0040 - val_loss: 0.0036
# Epoch 88/100
# 194/194 [==============================] - ETA: 0s - loss: 0.0040
# Epoch 88: saving model to checkpoints_LSTM_agg_holidays_hourly\model_epoch_88.h5
# 194/194 [==============================] - 79s 405ms/step - loss: 0.0040 - val_loss: 0.0037
# Epoch 89/100
# 194/194 [==============================] - ETA: 0s - loss: 0.0040
# Epoch 89: saving model to checkpoints_LSTM_agg_holidays_hourly\model_epoch_89.h5
# 194/194 [==============================] - 79s 405ms/step - loss: 0.0040 - val_loss: 0.0037
# Epoch 90/100
# 194/194 [==============================] - ETA: 0s - loss: 0.0040
# Epoch 90: saving model to checkpoints_LSTM_agg_holidays_hourly\model_epoch_90.h5
# 194/194 [==============================] - 79s 405ms/step - loss: 0.0040 - val_loss: 0.0040
# Epoch 91/100
# 194/194 [==============================] - ETA: 0s - loss: 0.0040
# Epoch 91: saving model to checkpoints_LSTM_agg_holidays_hourly\model_epoch_91.h5
# 194/194 [==============================] - 79s 405ms/step - loss: 0.0040 - val_loss: 0.0036
# Epoch 92/100
# 194/194 [==============================] - ETA: 0s - loss: 0.0039
# Epoch 92: saving model to checkpoints_LSTM_agg_holidays_hourly\model_epoch_92.h5
# 194/194 [==============================] - 79s 405ms/step - loss: 0.0039 - val_loss: 0.0037
# Epoch 93/100
# 194/194 [==============================] - ETA: 0s - loss: 0.0040
# Epoch 93: saving model to checkpoints_LSTM_agg_holidays_hourly\model_epoch_93.h5
# 194/194 [==============================] - 79s 405ms/step - loss: 0.0040 - val_loss: 0.0037
# Epoch 94/100
# 194/194 [==============================] - ETA: 0s - loss: 0.0039
# Epoch 94: saving model to checkpoints_LSTM_agg_holidays_hourly\model_epoch_94.h5
# 194/194 [==============================] - 79s 405ms/step - loss: 0.0039 - val_loss: 0.0037
# Epoch 95/100
# 194/194 [==============================] - ETA: 0s - loss: 0.0039
# Epoch 95: saving model to checkpoints_LSTM_agg_holidays_hourly\model_epoch_95.h5
# 194/194 [==============================] - 79s 405ms/step - loss: 0.0039 - val_loss: 0.0038
# Epoch 96/100
# 194/194 [==============================] - ETA: 0s - loss: 0.0039
# Epoch 96: saving model to checkpoints_LSTM_agg_holidays_hourly\model_epoch_96.h5
# 194/194 [==============================] - 79s 406ms/step - loss: 0.0039 - val_loss: 0.0036
# Epoch 97/100
# 194/194 [==============================] - ETA: 0s - loss: 0.0039
# Epoch 97: saving model to checkpoints_LSTM_agg_holidays_hourly\model_epoch_97.h5
# 194/194 [==============================] - 79s 405ms/step - loss: 0.0039 - val_loss: 0.0036
# Epoch 98/100
# 194/194 [==============================] - ETA: 0s - loss: 0.0039
# Epoch 98: saving model to checkpoints_LSTM_agg_holidays_hourly\model_epoch_98.h5
# 194/194 [==============================] - 79s 405ms/step - loss: 0.0039 - val_loss: 0.0036
# Epoch 99/100
# 194/194 [==============================] - ETA: 0s - loss: 0.0039
# Epoch 99: saving model to checkpoints_LSTM_agg_holidays_hourly\model_epoch_99.h5
# 194/194 [==============================] - 79s 405ms/step - loss: 0.0039 - val_loss: 0.0036
# Epoch 100/100
# 194/194 [==============================] - ETA: 0s - loss: 0.0039
# Epoch 100: saving model to checkpoints_LSTM_agg_holidays_hourly\model_epoch_100.h5
# 194/194 [==============================] - 79s 405ms/step - loss: 0.0039 - val_loss: 0.0037

# %%
plt.figure(figsize=(12, 6), dpi=200)

plt.plot(history.history['loss'], label='Training loss')
plt.plot(history.history['val_loss'], label='Validation loss')
plt.legend()
plt.title('Training and iteration loss through iterations')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
min_val_loss = min(history.history['val_loss'])
min_val_loss_epoch = np.argmin(history.history['val_loss']) + 1
print(f"Min validation loss of {min_val_loss} reached at epoch {min_val_loss_epoch}")
# Out:
# Minimum validation loss of 0.003559340722858906 reached at epoch 96

# %%
model = load_model('checkpoints_LSTM_hourly/model_epoch_96.h5')

pred = model.predict(x_test)
score = np.sqrt(metrics.mean_squared_error(pred,y_test))
print("Score (RMSE): {}".format(score))
# Out:
# 6/6 [==============================] - 23s 4s/step
# Score (RMSE): 0.059457443273147136

# %%
#upload test predictions to the database
pred = scaler.inverse_transform(pred)
data = [(float(element), i+1) for i, element in enumerate(pred)]
query = "UPDATE rq3_test_predictions_hourly SET lstm_nn = %s WHERE id = %s"
cursor.executemany(query, data)
db_connection.commit()
