# %%
import mysql.connector
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

db_connection = mysql.connector.connect(
  host="",
  user="",
  passwd="",
  database="mps_data"
)
cursor = db_connection.cursor()

query = '''
SELECT * FROM modelling_view
WHERE Date_time BETWEEN '2020-01-01 00:00:00' AND '2022-01-01 00:00:00';
'''
modelling_view = pd.read_sql(query, db_connection)
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_16084\1733514582.py:18: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   modelling_view = pd.read_sql(query, db_connection)

# %%
#create two groups for main_duty and borough based on the average max_tactic used in each group
#cut in performed at the median

avg_max_tactic_m = modelling_view.groupby('main_duty')['max_tactic'].mean()
main_duty_bins = pd.qcut(avg_max_tactic_m.values, q=2)
duty_to_group = {duty: int(group) for duty, group in zip(avg_max_tactic_m.index, main_duty_bins.codes)}
modelling_view['main_duty_group'] = modelling_view['main_duty'].map(duty_to_group)
print(modelling_view['main_duty_group'].value_counts())

avg_max_tactic_b = modelling_view.groupby('borough')['max_tactic'].mean()
main_borough_bins = pd.qcut(avg_max_tactic_b.values, q=2)
borough_to_group = {borough: int(group) for borough, group in zip(avg_max_tactic_b.index, main_borough_bins.codes)}
modelling_view['borough_group'] = modelling_view['borough'].map(borough_to_group)
print(modelling_view['borough_group'].value_counts())
# Out:
# 0    276035
# 1     17805
# Name: main_duty_group, dtype: int64
# 1    148934
# 0    144906
# Name: borough_group, dtype: int64

# %%
#display the distribution of a target variable
print(modelling_view['primary_conduct'].value_counts())
#randomly shuffle the data
modelling_view = modelling_view.sample(frac=1, random_state=1)

#perform the binning of the data to get 3 classes of primary conduct
modelling_view['primary_conduct_mcl'] = modelling_view['primary_conduct'].apply(lambda x: 0 if x == 0 else (1 if x in [1, 2] else 2))
print(modelling_view['primary_conduct_mcl'].value_counts())
# Out:
# 0    131470
# 3     51969
# 2     41890
# 4     32385
# 1     27032
# 5      9094
# Name: primary_conduct, dtype: int64
# 0    131470
# 2     93448
# 1     68922
# Name: primary_conduct_mcl, dtype: int64

# %%
#perform undersampling of the test data to balance the classes

#separate the classes
class_0 = modelling_view[modelling_view['primary_conduct_mcl'] == 0]
class_1 = modelling_view[modelling_view['primary_conduct_mcl'] == 1]
class_2 = modelling_view[modelling_view['primary_conduct_mcl'] == 2]

#determine the number of samples in the smallest class
n_samples = min(len(class_0), len(class_1), len(class_2))

#sample all the classes to the number of samples in the smallest class
class_0_under = class_0.sample(n_samples, random_state=1)
class_1_under = class_1.sample(n_samples, random_state=1)
class_2_under = class_2.sample(n_samples, random_state=1)

#concatenate the classes into a dataframe
df_under = pd.concat([class_0_under, class_1_under, class_2_under], axis=0)

#check the number of samples in each class
print(df_under['primary_conduct_mcl'].value_counts())
# Out:
# 0    68922
# 1    68922
# 2    68922
# Name: primary_conduct_mcl, dtype: int64

# %%
#separate the training data into X and y (predictors and response)
#while dropping the irrelavant predictors
X_train = df_under.drop(['date_time', 'main_duty', 'borough', 
                        'non_compliant', 'physical_force_applied', 'max_tactic',
                        'year', 'primary_conduct', 'primary_conduct_mcl'], axis=1)
y_train = df_under['primary_conduct_mcl']

# %%
#import the libraries necessary for XGBoost
import xgboost as xgb
from sklearn.model_selection import GridSearchCV, StratifiedKFold
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, auc, accuracy_score

# %%
#perform the grid search to determine the set of optimal hyperparameters for this data

#define the XGB classifier object with the GPU acceleration support
gb_model = xgb.XGBClassifier(tree_method='gpu_hist')
#define the grid of hyperparameters for gridsearch
gb_param_grid = {
    'learning_rate': [0.1, 0.01],
    'n_estimators': [250],
    'max_depth': [3, 5, 7, 9, 10]
}
#perform the grid search using stratified 10-fold cross-validation
gb_grid_search = GridSearchCV(gb_model,
                              param_grid=gb_param_grid,
                              cv=StratifiedKFold(n_splits=10),
                              scoring='accuracy',
                              n_jobs=-1).fit(X_train, y_train)
#extract the best set of parameters and the corresponding accuracy score
print("Best hyperparameters:", gb_grid_search.best_params_)
print("Accuracy:", gb_grid_search.best_score_)
# Out:
# Best parameters: {'learning_rate': 0.1, 'max_depth': 9, 'n_estimators': 250}
# Accuracy: 0.49439945979119476

# %%
#retrieve the best hyperparameters obtained from the grid search
# gb_best_params = gb_grid_search.best_params_
gb_best_params = {'learning_rate': 0.1, 'max_depth': 9, 'n_estimators': 250}
#create a xgboost classifier passing the hyperparameters
gb_model = xgb.XGBClassifier(
    tree_method='gpu_hist',
    learning_rate=gb_best_params['learning_rate'],
    n_estimators=gb_best_params['n_estimators'],
    max_depth=gb_best_params['max_depth'],
    n_jobs=-1,
)
#fit the xgboost classifier using training data
gb_model.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.1, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=9, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=250, n_jobs=-1, num_parallel_tree=None,
#               objective='multi:softprob', predictor=None, ...)

# %%
#extract and visualise the feature importances from the fitted model

#extract importance values and feature names
feature_importances = gb_model.feature_importances_
feature_names = X_train.columns.tolist()
#filter out the importances that account for less than 2% of the total importance
filtered_indices = np.where(np.abs(feature_importances) >= 0.02)[0]
filtered_importances = feature_importances[filtered_indices]
filtered_feature_names = np.array(feature_names)[filtered_indices]
#sort the importances and feature names
sorted_indices = np.argsort(filtered_importances)
sorted_importances = filtered_importances[sorted_indices]
sorted_feature_names = filtered_feature_names[sorted_indices]
#positions of the bars on the y-axis
y_pos = np.arange(len(sorted_feature_names))
#define the font size and family
plt.rcParams['font.family'] = 'serif'
plt.rcParams['font.size'] = 8
#plot the horizontal bar chart with feature importances
plt.figure(figsize=(5, 4), dpi=300)
bars = plt.barh(y_pos, sorted_importances, align='center', alpha=0.7)
#add the labels with values to
for bar in bars:
    #get the width of the bar
    width = bar.get_width()
    #display the value next to the bar
    plt.text(width, bar.get_y() + bar.get_height()/2, f"{width:.2f}", 
             ha='left' if width < 0 else 'right', va='center', color='black')
#add the feature names to the y axis
plt.yticks(y_pos, sorted_feature_names)
#add the title and axis labels
plt.ylabel('Features')
plt.xlabel('Feature Importance')
plt.title('Feature importances')
plt.tight_layout()
#save the plot to a file and display it
plt.savefig('feature_importances_xgboost.png', dpi=200)
plt.show()

# %%
#extract the testing data from the database
query = '''
SELECT * FROM modelling_view
WHERE Date_time BETWEEN '2022-01-01 00:00:00' AND '2022-04-01 00:00:00';
'''
modelling_view_test = pd.read_sql(query, db_connection)
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_16084\2268738141.py:6: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   modelling_view_test = pd.read_sql(query, db_connection)

# %%
modelling_view_test['main_duty_group'] = modelling_view_test['main_duty'].map(duty_to_group)
print(modelling_view_test['main_duty_group'].value_counts())
modelling_view_test['borough_group'] = modelling_view_test['borough'].map(borough_to_group)
print(modelling_view_test['borough_group'].value_counts())

modelling_view_test['primary_conduct_mcl'] = modelling_view_test['primary_conduct'].apply(lambda x: 0 if x == 0 else (1 if x in [1, 2] else 2))
print(modelling_view_test['primary_conduct_mcl'].value_counts())

X_test = modelling_view_test.drop(['date_time', 'main_duty', 'borough', 
                        'non_compliant', 'physical_force_applied', 'max_tactic',
                        'year', 'primary_conduct', 'primary_conduct_mcl'], axis=1)
y_test = modelling_view_test['primary_conduct_mcl']
# Out:
# 0    29682
# 1     1701
# Name: main_duty_group, dtype: int64
# 1    15940
# 0    15443
# Name: borough_group, dtype: int64
# 0    13419
# 2    10374
# 1     7590
# Name: primary_conduct_mcl, dtype: int64

# %%
#extract the predicted probabilities and convert them to class labels
predicted_proba = gb_model.predict_proba(X_test)
predicted_labels = np.argmax(predicted_proba, axis=1)
#calculate and print the accuracy
print(f"Accuracy: {accuracy_score(y_test, predicted_labels)}")
# Out:
# Accuracy: 0.49240034413535994

# %%
#insert the observed test values into the database
data_tuples = [(int(element),) for element in y_test.to_numpy()]
query = "INSERT INTO rq2_test_predictions (true_label) VALUES (%s);"
cursor.executemany(query, data_tuples)
db_connection.commit()

# %%
#arrange the data in a list of tuples
data_tuples = [(float(element[0]), float(element[1]), float(element[2])) for element in gb_model.predict_proba(X_test)]
#create a temporary table in a database
cursor.execute("DROP TABLE IF EXISTS temp_table")
cursor.execute("""
    CREATE TEMPORARY TABLE temp_table (
        id SERIAL PRIMARY KEY,
        xgb_0 FLOAT,
        xgb_1 FLOAT,
        xgb_2 FLOAT
    )
""")
#bulk insert data into temporary table
query = "INSERT INTO temp_table (xgb_0, xgb_1, xgb_2) VALUES (%s, %s, %s);"
cursor.executemany(query, data_tuples)
#update the table using the temporary table
cursor.execute("""
    UPDATE rq2_test_predictions 
    JOIN temp_table 
    ON rq2_test_predictions.id = temp_table.id
    SET 
        rq2_test_predictions.xgb_0 = temp_table.xgb_0, 
        rq2_test_predictions.xgb_1 = temp_table.xgb_1, 
        rq2_test_predictions.xgb_2 = temp_table.xgb_2
""")
#commit the transaction
db_connection.commit()

# %% [markdown]
# ### Regularized Multinomial Logistic Regression

# %%
#import the libraries necessary for logistic regression modelling
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler

#standardize the predictors
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)
#define the logistic regression object
lr_model = LogisticRegression(multi_class='multinomial', penalty='elasticnet', solver='saga', random_state=1)
#define the hyperparameter grid for optimization
param_grid = {
    'C': [0.01, 0.1, 1, 10, 100],
    'l1_ratio': [0, 0.1, 0.5, 0.9, 1]
}
#perform the grid search using stratified 10-fold cross validation
grid_lr_model = GridSearchCV(lr_model, 
                        param_grid, 
                        cv=StratifiedKFold(n_splits=10), 
                        scoring='accuracy',
                        n_jobs=-1,
                        verbose=1)
grid_lr_model.fit(X_train_scaled, y_train)

#extract the best parameters and the best score
print("Best parameters: ", grid_lr_model.best_params_)
print("Accuracy:", grid_lr_model.best_score_)
# Out:
# Fitting 10 folds for each of 25 candidates, totalling 250 fits
# Best parameters:  {'C': 0.01, 'l1_ratio': 0.5}
# Accuracy: 0.47539245163144744

# %%
lr_model = LogisticRegression(random_state=1, multi_class='multinomial', 
                              penalty='elasticnet', solver='saga', C=0.01, l1_ratio=0.5)
lr_model.fit(X_train_scaled, y_train)
y_pred = lr_model.predict(X_test_scaled)

print("Accuracy: {}".format(accuracy_score(y_test, y_pred)))
# Out:
# Accuracy: 0.5129847369595004

# %%
data_tuples = [(float(element[0]), float(element[1]), float(element[2])) for element in lr_model.predict_proba(X_test_scaled)]
cursor.execute("DROP TABLE IF EXISTS temp_table")
cursor.execute("""
    CREATE TEMPORARY TABLE temp_table (
        id SERIAL PRIMARY KEY,
        logreg_0 FLOAT,
        logreg_1 FLOAT,
        logreg_2 FLOAT
    )
""")
query = "INSERT INTO temp_table (logreg_0, logreg_1, logreg_2) VALUES (%s, %s, %s);"
cursor.executemany(query, data_tuples)
cursor.execute("""
    UPDATE rq2_test_predictions 
    JOIN temp_table 
    ON rq2_test_predictions.id = temp_table.id
    SET 
        rq2_test_predictions.logreg_0 = temp_table.logreg_0, 
        rq2_test_predictions.logreg_1 = temp_table.logreg_1, 
        rq2_test_predictions.logreg_2 = temp_table.logreg_2
""")
db_connection.commit()

# %%
#display the normalized coefficients of the logistic regression model

coef = lr_model.coef_
non_zero_indices = np.where(np.abs(coef[2]) > 0.01)[0]  
filtered_coef = coef[2][non_zero_indices]
filtered_feature_names = np.array(feature_names)[non_zero_indices]

sorted_indices = np.argsort(-filtered_coef)
sorted_coef = filtered_coef[sorted_indices]
sorted_feature_names = filtered_feature_names[sorted_indices]

y_pos = np.arange(len(sorted_coef))

plt.rcParams['font.family'] = 'serif'
plt.rcParams['font.size'] = 6
plt.figure(figsize=(5, 5), dpi=300)
bars = plt.barh(y_pos, sorted_coef, align='center', alpha=0.7)

for bar in bars:
    width = bar.get_width()
    plt.text(width, bar.get_y() + bar.get_height()/2, f"{width:.2f}", ha='left' if width < 0 else 'right', va='center', color='black')

plt.yticks(y_pos, sorted_feature_names)
plt.ylabel('Features')
plt.xlabel('Coefficient Value')
plt.title('Regression coefficients')
plt.tight_layout()
plt.savefig('logreg_coefficients.png', dpi=300)
plt.show()

# %% [markdown]
# ### Neural Network

# %%
#import the libraries necessary for deep learning

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.metrics import AUC
from tensorflow.keras import regularizers
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder, StandardScaler, MinMaxScaler
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
import os

#check the GPU availability
print(tf.config.experimental.list_physical_devices('GPU'))
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
#scale the non-binary predictor variables using min-max scaling (binary variables are already scaled)
scaler = MinMaxScaler()
non_binary_columns = ['month',
 'day_of_month',
 'day_of_week',
 'hour_of_day',
 'subject_age',
 'census_not_deprived',
 'census_white_ethnic',
 'census_no_heating',
 'census_heterosexual',
 'census_gay_lesbian',
 'census_no_answer_orientation',
 'census_pop_density',
 'census_low_qualification',
 'census_high_qualification',
 'census_born_uk',
 'census_student',
 'mps_crime_rate'
 ]
X_train[non_binary_columns] = scaler.fit_transform(X_train[non_binary_columns])
X_test[non_binary_columns] = scaler.fit_transform(X_test[non_binary_columns])

# %%
#split the training data into training and validation sets
X_train, X_val, y_train, y_val = train_test_split(
    X_train, y_train, test_size=0.2, random_state=1, stratify=y_train.values.reshape(-1, 1)
)

# %%
#one hot encoding for target variables
y_train_encoded = to_categorical(y_train)
y_val_encoded = to_categorical(y_val)
y_test_encoded = to_categorical(y_test)

# %%
#define the neural network architecture
model = Sequential()
model.add(Dense(units=64, activation='relu', input_shape=(X_train.shape[1],)))
model.add(Dropout(0.1))
model.add(Dense(units=128, activation='relu', 
                kernel_regularizer=regularizers.l2(0.01)))
model.add(Dropout(0.2))
model.add(Dense(units=64, activation='relu', 
                kernel_regularizer=regularizers.l2(0.01)))
model.add(Dropout(0.1))
model.add(Dense(units=32, activation='relu'))
model.add(Dense(units=16, activation='relu'))
model.add(Dense(units=y_train_encoded.shape[1], activation='softmax'))

# %%
#define the early stopping criteria (stop the training if validation loss doesnt improve for 20 consequtive epochs)
earlystop = EarlyStopping(monitor='val_loss', patience=20, verbose=1)
#define the model checkpoint to save the models after every training epoch
os.makedirs("checkpoints_RS2_NN", exist_ok=True)
checkpoint = ModelCheckpoint('checkpoints_RS2_NN/model_epoch_{epoch:02d}.h5', 
                                   monitor='val_loss', verbose=1, save_best_only=False, mode='min')

# %%
#compile the model
model.compile(optimizer=Adam(learning_rate=0.00001), 
              loss='categorical_crossentropy', 
              metrics='accuracy')
#fit the model (saving the history of training)
history = model.fit(X_train, y_train_encoded, epochs=300, batch_size=128, 
                    validation_data=(X_val, y_val_encoded), verbose=1, 
                    callbacks=[earlystop, checkpoint])
# Out:
# Epoch 1/300
# 1282/1293 [============================>.] - ETA: 0s - loss: 2.6703 - accuracy: 0.3377
# Epoch 1: saving model to checkpoints_RS2_NN\model_epoch_01.h5
# 1293/1293 [==============================] - 7s 5ms/step - loss: 2.6691 - accuracy: 0.3379 - val_loss: 2.5134 - val_accuracy: 0.3675
# Epoch 2/300
# 1287/1293 [============================>.] - ETA: 0s - loss: 2.3771 - accuracy: 0.3695
# Epoch 2: saving model to checkpoints_RS2_NN\model_epoch_02.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 2.3766 - accuracy: 0.3696 - val_loss: 2.2421 - val_accuracy: 0.4181
# Epoch 3/300
# 1286/1293 [============================>.] - ETA: 0s - loss: 2.1255 - accuracy: 0.4012
# Epoch 3: saving model to checkpoints_RS2_NN\model_epoch_03.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 2.1250 - accuracy: 0.4012 - val_loss: 2.0056 - val_accuracy: 0.4353
# Epoch 4/300
# 1291/1293 [============================>.] - ETA: 0s - loss: 1.9078 - accuracy: 0.4214
# Epoch 4: saving model to checkpoints_RS2_NN\model_epoch_04.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.9077 - accuracy: 0.4214 - val_loss: 1.8034 - val_accuracy: 0.4424
# Epoch 5/300
# 1291/1293 [============================>.] - ETA: 0s - loss: 1.7251 - accuracy: 0.4322
# Epoch 5: saving model to checkpoints_RS2_NN\model_epoch_05.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.7251 - accuracy: 0.4322 - val_loss: 1.6371 - val_accuracy: 0.4507
# Epoch 6/300
# 1288/1293 [============================>.] - ETA: 0s - loss: 1.5753 - accuracy: 0.4415
# Epoch 6: saving model to checkpoints_RS2_NN\model_epoch_06.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.5752 - accuracy: 0.4414 - val_loss: 1.5022 - val_accuracy: 0.4549
# Epoch 7/300
# 1286/1293 [============================>.] - ETA: 0s - loss: 1.4558 - accuracy: 0.4448
# Epoch 7: saving model to checkpoints_RS2_NN\model_epoch_07.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.4555 - accuracy: 0.4449 - val_loss: 1.3950 - val_accuracy: 0.4582
# Epoch 8/300
# 1292/1293 [============================>.] - ETA: 0s - loss: 1.3593 - accuracy: 0.4486
# Epoch 8: saving model to checkpoints_RS2_NN\model_epoch_08.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.3593 - accuracy: 0.4486 - val_loss: 1.3099 - val_accuracy: 0.4605
# Epoch 9/300
# 1284/1293 [============================>.] - ETA: 0s - loss: 1.2834 - accuracy: 0.4513
# Epoch 9: saving model to checkpoints_RS2_NN\model_epoch_09.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.2832 - accuracy: 0.4512 - val_loss: 1.2436 - val_accuracy: 0.4618
# Epoch 10/300
# 1284/1293 [============================>.] - ETA: 0s - loss: 1.2247 - accuracy: 0.4538
# Epoch 10: saving model to checkpoints_RS2_NN\model_epoch_10.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.2245 - accuracy: 0.4540 - val_loss: 1.1925 - val_accuracy: 0.4634
# Epoch 11/300
# 1285/1293 [============================>.] - ETA: 0s - loss: 1.1796 - accuracy: 0.4559
# Epoch 11: saving model to checkpoints_RS2_NN\model_epoch_11.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.1796 - accuracy: 0.4557 - val_loss: 1.1540 - val_accuracy: 0.4644
# Epoch 12/300
# 1289/1293 [============================>.] - ETA: 0s - loss: 1.1458 - accuracy: 0.4581
# Epoch 12: saving model to checkpoints_RS2_NN\model_epoch_12.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.1457 - accuracy: 0.4582 - val_loss: 1.1258 - val_accuracy: 0.4655
# Epoch 13/300
# 1287/1293 [============================>.] - ETA: 0s - loss: 1.1220 - accuracy: 0.4583
# Epoch 13: saving model to checkpoints_RS2_NN\model_epoch_13.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.1219 - accuracy: 0.4584 - val_loss: 1.1056 - val_accuracy: 0.4664
# Epoch 14/300
# 1289/1293 [============================>.] - ETA: 0s - loss: 1.1048 - accuracy: 0.4594
# Epoch 14: saving model to checkpoints_RS2_NN\model_epoch_14.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.1048 - accuracy: 0.4594 - val_loss: 1.0913 - val_accuracy: 0.4654
# Epoch 15/300
# 1285/1293 [============================>.] - ETA: 0s - loss: 1.0922 - accuracy: 0.4599
# Epoch 15: saving model to checkpoints_RS2_NN\model_epoch_15.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0921 - accuracy: 0.4601 - val_loss: 1.0809 - val_accuracy: 0.4662
# Epoch 16/300
# 1290/1293 [============================>.] - ETA: 0s - loss: 1.0830 - accuracy: 0.4610
# Epoch 16: saving model to checkpoints_RS2_NN\model_epoch_16.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0830 - accuracy: 0.4611 - val_loss: 1.0731 - val_accuracy: 0.4677
# Epoch 17/300
# 1283/1293 [============================>.] - ETA: 0s - loss: 1.0755 - accuracy: 0.4618
# Epoch 17: saving model to checkpoints_RS2_NN\model_epoch_17.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0754 - accuracy: 0.4619 - val_loss: 1.0670 - val_accuracy: 0.4674
# Epoch 18/300
# 1283/1293 [============================>.] - ETA: 0s - loss: 1.0697 - accuracy: 0.4613
# Epoch 18: saving model to checkpoints_RS2_NN\model_epoch_18.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0696 - accuracy: 0.4614 - val_loss: 1.0620 - val_accuracy: 0.4673
# Epoch 19/300
# 1289/1293 [============================>.] - ETA: 0s - loss: 1.0654 - accuracy: 0.4617
# Epoch 19: saving model to checkpoints_RS2_NN\model_epoch_19.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0654 - accuracy: 0.4616 - val_loss: 1.0579 - val_accuracy: 0.4682
# Epoch 20/300
# 1291/1293 [============================>.] - ETA: 0s - loss: 1.0612 - accuracy: 0.4621
# Epoch 20: saving model to checkpoints_RS2_NN\model_epoch_20.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0611 - accuracy: 0.4622 - val_loss: 1.0542 - val_accuracy: 0.4682
# Epoch 21/300
# 1284/1293 [============================>.] - ETA: 0s - loss: 1.0574 - accuracy: 0.4641
# Epoch 21: saving model to checkpoints_RS2_NN\model_epoch_21.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0575 - accuracy: 0.4640 - val_loss: 1.0511 - val_accuracy: 0.4683
# Epoch 22/300
# 1285/1293 [============================>.] - ETA: 0s - loss: 1.0547 - accuracy: 0.4639
# Epoch 22: saving model to checkpoints_RS2_NN\model_epoch_22.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0547 - accuracy: 0.4637 - val_loss: 1.0483 - val_accuracy: 0.4686
# Epoch 23/300
# 1282/1293 [============================>.] - ETA: 0s - loss: 1.0515 - accuracy: 0.4637
# Epoch 23: saving model to checkpoints_RS2_NN\model_epoch_23.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0514 - accuracy: 0.4638 - val_loss: 1.0459 - val_accuracy: 0.4679
# Epoch 24/300
# 1290/1293 [============================>.] - ETA: 0s - loss: 1.0495 - accuracy: 0.4643
# Epoch 24: saving model to checkpoints_RS2_NN\model_epoch_24.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0495 - accuracy: 0.4642 - val_loss: 1.0437 - val_accuracy: 0.4684
# Epoch 25/300
# 1286/1293 [============================>.] - ETA: 0s - loss: 1.0472 - accuracy: 0.4656
# Epoch 25: saving model to checkpoints_RS2_NN\model_epoch_25.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0471 - accuracy: 0.4656 - val_loss: 1.0419 - val_accuracy: 0.4690
# Epoch 26/300
# 1288/1293 [============================>.] - ETA: 0s - loss: 1.0451 - accuracy: 0.4654
# Epoch 26: saving model to checkpoints_RS2_NN\model_epoch_26.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0450 - accuracy: 0.4655 - val_loss: 1.0401 - val_accuracy: 0.4682
# Epoch 27/300
# 1287/1293 [============================>.] - ETA: 0s - loss: 1.0434 - accuracy: 0.4654
# Epoch 27: saving model to checkpoints_RS2_NN\model_epoch_27.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0435 - accuracy: 0.4654 - val_loss: 1.0385 - val_accuracy: 0.4691
# Epoch 28/300
# 1290/1293 [============================>.] - ETA: 0s - loss: 1.0420 - accuracy: 0.4663
# Epoch 28: saving model to checkpoints_RS2_NN\model_epoch_28.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0419 - accuracy: 0.4664 - val_loss: 1.0371 - val_accuracy: 0.4689
# Epoch 29/300
# 1284/1293 [============================>.] - ETA: 0s - loss: 1.0406 - accuracy: 0.4660
# Epoch 29: saving model to checkpoints_RS2_NN\model_epoch_29.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0405 - accuracy: 0.4661 - val_loss: 1.0359 - val_accuracy: 0.4691
# Epoch 30/300
# 1290/1293 [============================>.] - ETA: 0s - loss: 1.0390 - accuracy: 0.4673
# Epoch 30: saving model to checkpoints_RS2_NN\model_epoch_30.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0390 - accuracy: 0.4673 - val_loss: 1.0349 - val_accuracy: 0.4704
# Epoch 31/300
# 1289/1293 [============================>.] - ETA: 0s - loss: 1.0374 - accuracy: 0.4662
# Epoch 31: saving model to checkpoints_RS2_NN\model_epoch_31.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0373 - accuracy: 0.4662 - val_loss: 1.0335 - val_accuracy: 0.4704
# Epoch 32/300
# 1284/1293 [============================>.] - ETA: 0s - loss: 1.0369 - accuracy: 0.4659
# Epoch 32: saving model to checkpoints_RS2_NN\model_epoch_32.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0369 - accuracy: 0.4658 - val_loss: 1.0326 - val_accuracy: 0.4710
# Epoch 33/300
# 1293/1293 [==============================] - ETA: 0s - loss: 1.0360 - accuracy: 0.4651
# Epoch 33: saving model to checkpoints_RS2_NN\model_epoch_33.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0360 - accuracy: 0.4651 - val_loss: 1.0316 - val_accuracy: 0.4708
# Epoch 34/300
# 1288/1293 [============================>.] - ETA: 0s - loss: 1.0350 - accuracy: 0.4665
# Epoch 34: saving model to checkpoints_RS2_NN\model_epoch_34.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0350 - accuracy: 0.4664 - val_loss: 1.0308 - val_accuracy: 0.4708
# Epoch 35/300
# 1291/1293 [============================>.] - ETA: 0s - loss: 1.0341 - accuracy: 0.4665
# Epoch 35: saving model to checkpoints_RS2_NN\model_epoch_35.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0341 - accuracy: 0.4665 - val_loss: 1.0300 - val_accuracy: 0.4715
# Epoch 36/300
# 1287/1293 [============================>.] - ETA: 0s - loss: 1.0330 - accuracy: 0.4665
# Epoch 36: saving model to checkpoints_RS2_NN\model_epoch_36.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0330 - accuracy: 0.4666 - val_loss: 1.0293 - val_accuracy: 0.4705
# Epoch 37/300
# 1291/1293 [============================>.] - ETA: 0s - loss: 1.0320 - accuracy: 0.4668
# Epoch 37: saving model to checkpoints_RS2_NN\model_epoch_37.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0320 - accuracy: 0.4668 - val_loss: 1.0286 - val_accuracy: 0.4703
# Epoch 38/300
# 1288/1293 [============================>.] - ETA: 0s - loss: 1.0320 - accuracy: 0.4668
# Epoch 38: saving model to checkpoints_RS2_NN\model_epoch_38.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0319 - accuracy: 0.4670 - val_loss: 1.0280 - val_accuracy: 0.4715
# Epoch 39/300
# 1282/1293 [============================>.] - ETA: 0s - loss: 1.0310 - accuracy: 0.4670
# Epoch 39: saving model to checkpoints_RS2_NN\model_epoch_39.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0310 - accuracy: 0.4670 - val_loss: 1.0273 - val_accuracy: 0.4717
# Epoch 40/300
# 1282/1293 [============================>.] - ETA: 0s - loss: 1.0305 - accuracy: 0.4665
# Epoch 40: saving model to checkpoints_RS2_NN\model_epoch_40.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0306 - accuracy: 0.4662 - val_loss: 1.0268 - val_accuracy: 0.4707
# Epoch 41/300
# 1281/1293 [============================>.] - ETA: 0s - loss: 1.0297 - accuracy: 0.4675
# Epoch 41: saving model to checkpoints_RS2_NN\model_epoch_41.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0298 - accuracy: 0.4674 - val_loss: 1.0263 - val_accuracy: 0.4720
# Epoch 42/300
# 1288/1293 [============================>.] - ETA: 0s - loss: 1.0292 - accuracy: 0.4679
# Epoch 42: saving model to checkpoints_RS2_NN\model_epoch_42.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0292 - accuracy: 0.4679 - val_loss: 1.0258 - val_accuracy: 0.4715
# Epoch 43/300
# 1287/1293 [============================>.] - ETA: 0s - loss: 1.0283 - accuracy: 0.4686
# Epoch 43: saving model to checkpoints_RS2_NN\model_epoch_43.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0283 - accuracy: 0.4687 - val_loss: 1.0254 - val_accuracy: 0.4727
# Epoch 44/300
# 1283/1293 [============================>.] - ETA: 0s - loss: 1.0280 - accuracy: 0.4694
# Epoch 44: saving model to checkpoints_RS2_NN\model_epoch_44.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0281 - accuracy: 0.4692 - val_loss: 1.0248 - val_accuracy: 0.4726
# Epoch 45/300
# 1292/1293 [============================>.] - ETA: 0s - loss: 1.0275 - accuracy: 0.4689
# Epoch 45: saving model to checkpoints_RS2_NN\model_epoch_45.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0275 - accuracy: 0.4690 - val_loss: 1.0244 - val_accuracy: 0.4724
# Epoch 46/300
# 1284/1293 [============================>.] - ETA: 0s - loss: 1.0271 - accuracy: 0.4684
# Epoch 46: saving model to checkpoints_RS2_NN\model_epoch_46.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0272 - accuracy: 0.4684 - val_loss: 1.0240 - val_accuracy: 0.4728
# Epoch 47/300
# 1282/1293 [============================>.] - ETA: 0s - loss: 1.0270 - accuracy: 0.4684
# Epoch 47: saving model to checkpoints_RS2_NN\model_epoch_47.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0270 - accuracy: 0.4685 - val_loss: 1.0237 - val_accuracy: 0.4723
# Epoch 48/300
# 1290/1293 [============================>.] - ETA: 0s - loss: 1.0263 - accuracy: 0.4689
# Epoch 48: saving model to checkpoints_RS2_NN\model_epoch_48.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0263 - accuracy: 0.4690 - val_loss: 1.0233 - val_accuracy: 0.4721
# Epoch 49/300
# 1288/1293 [============================>.] - ETA: 0s - loss: 1.0260 - accuracy: 0.4690
# Epoch 49: saving model to checkpoints_RS2_NN\model_epoch_49.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0259 - accuracy: 0.4691 - val_loss: 1.0230 - val_accuracy: 0.4717
# Epoch 50/300
# 1287/1293 [============================>.] - ETA: 0s - loss: 1.0257 - accuracy: 0.4686
# Epoch 50: saving model to checkpoints_RS2_NN\model_epoch_50.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0256 - accuracy: 0.4687 - val_loss: 1.0228 - val_accuracy: 0.4719
# Epoch 51/300
# 1282/1293 [============================>.] - ETA: 0s - loss: 1.0251 - accuracy: 0.4692
# Epoch 51: saving model to checkpoints_RS2_NN\model_epoch_51.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0251 - accuracy: 0.4693 - val_loss: 1.0223 - val_accuracy: 0.4731
# Epoch 52/300
# 1291/1293 [============================>.] - ETA: 0s - loss: 1.0253 - accuracy: 0.4683
# Epoch 52: saving model to checkpoints_RS2_NN\model_epoch_52.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0253 - accuracy: 0.4683 - val_loss: 1.0221 - val_accuracy: 0.4729
# Epoch 53/300
# 1284/1293 [============================>.] - ETA: 0s - loss: 1.0250 - accuracy: 0.4678
# Epoch 53: saving model to checkpoints_RS2_NN\model_epoch_53.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0250 - accuracy: 0.4678 - val_loss: 1.0218 - val_accuracy: 0.4732
# Epoch 54/300
# 1290/1293 [============================>.] - ETA: 0s - loss: 1.0243 - accuracy: 0.4689
# Epoch 54: saving model to checkpoints_RS2_NN\model_epoch_54.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0243 - accuracy: 0.4690 - val_loss: 1.0215 - val_accuracy: 0.4734
# Epoch 55/300
# 1284/1293 [============================>.] - ETA: 0s - loss: 1.0241 - accuracy: 0.4690
# Epoch 55: saving model to checkpoints_RS2_NN\model_epoch_55.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0241 - accuracy: 0.4690 - val_loss: 1.0212 - val_accuracy: 0.4741
# Epoch 56/300
# 1287/1293 [============================>.] - ETA: 0s - loss: 1.0240 - accuracy: 0.4688
# Epoch 56: saving model to checkpoints_RS2_NN\model_epoch_56.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0239 - accuracy: 0.4690 - val_loss: 1.0210 - val_accuracy: 0.4734
# Epoch 57/300
# 1286/1293 [============================>.] - ETA: 0s - loss: 1.0239 - accuracy: 0.4687
# Epoch 57: saving model to checkpoints_RS2_NN\model_epoch_57.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0239 - accuracy: 0.4688 - val_loss: 1.0208 - val_accuracy: 0.4735
# Epoch 58/300
# 1292/1293 [============================>.] - ETA: 0s - loss: 1.0234 - accuracy: 0.4697
# Epoch 58: saving model to checkpoints_RS2_NN\model_epoch_58.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0234 - accuracy: 0.4698 - val_loss: 1.0206 - val_accuracy: 0.4734
# Epoch 59/300
# 1288/1293 [============================>.] - ETA: 0s - loss: 1.0232 - accuracy: 0.4704
# Epoch 59: saving model to checkpoints_RS2_NN\model_epoch_59.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0231 - accuracy: 0.4704 - val_loss: 1.0204 - val_accuracy: 0.4733
# Epoch 60/300
# 1291/1293 [============================>.] - ETA: 0s - loss: 1.0229 - accuracy: 0.4695
# Epoch 60: saving model to checkpoints_RS2_NN\model_epoch_60.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0229 - accuracy: 0.4694 - val_loss: 1.0202 - val_accuracy: 0.4737
# Epoch 61/300
# 1285/1293 [============================>.] - ETA: 0s - loss: 1.0224 - accuracy: 0.4698
# Epoch 61: saving model to checkpoints_RS2_NN\model_epoch_61.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0225 - accuracy: 0.4696 - val_loss: 1.0199 - val_accuracy: 0.4738
# Epoch 62/300
# 1288/1293 [============================>.] - ETA: 0s - loss: 1.0223 - accuracy: 0.4704
# Epoch 62: saving model to checkpoints_RS2_NN\model_epoch_62.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0222 - accuracy: 0.4705 - val_loss: 1.0198 - val_accuracy: 0.4733
# Epoch 63/300
# 1291/1293 [============================>.] - ETA: 0s - loss: 1.0225 - accuracy: 0.4695
# Epoch 63: saving model to checkpoints_RS2_NN\model_epoch_63.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0224 - accuracy: 0.4695 - val_loss: 1.0196 - val_accuracy: 0.4748
# Epoch 64/300
# 1286/1293 [============================>.] - ETA: 0s - loss: 1.0219 - accuracy: 0.4702
# Epoch 64: saving model to checkpoints_RS2_NN\model_epoch_64.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0219 - accuracy: 0.4703 - val_loss: 1.0194 - val_accuracy: 0.4744
# Epoch 65/300
# 1284/1293 [============================>.] - ETA: 0s - loss: 1.0218 - accuracy: 0.4705
# Epoch 65: saving model to checkpoints_RS2_NN\model_epoch_65.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0218 - accuracy: 0.4705 - val_loss: 1.0193 - val_accuracy: 0.4745
# Epoch 66/300
# 1291/1293 [============================>.] - ETA: 0s - loss: 1.0217 - accuracy: 0.4706
# Epoch 66: saving model to checkpoints_RS2_NN\model_epoch_66.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0217 - accuracy: 0.4706 - val_loss: 1.0191 - val_accuracy: 0.4742
# Epoch 67/300
# 1282/1293 [============================>.] - ETA: 0s - loss: 1.0219 - accuracy: 0.4691
# Epoch 67: saving model to checkpoints_RS2_NN\model_epoch_67.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0218 - accuracy: 0.4693 - val_loss: 1.0190 - val_accuracy: 0.4749
# Epoch 68/300
# 1289/1293 [============================>.] - ETA: 0s - loss: 1.0214 - accuracy: 0.4703
# Epoch 68: saving model to checkpoints_RS2_NN\model_epoch_68.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0213 - accuracy: 0.4705 - val_loss: 1.0188 - val_accuracy: 0.4740
# Epoch 69/300
# 1291/1293 [============================>.] - ETA: 0s - loss: 1.0212 - accuracy: 0.4697
# Epoch 69: saving model to checkpoints_RS2_NN\model_epoch_69.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0212 - accuracy: 0.4696 - val_loss: 1.0187 - val_accuracy: 0.4746
# Epoch 70/300
# 1284/1293 [============================>.] - ETA: 0s - loss: 1.0215 - accuracy: 0.4701
# Epoch 70: saving model to checkpoints_RS2_NN\model_epoch_70.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0215 - accuracy: 0.4701 - val_loss: 1.0186 - val_accuracy: 0.4746
# Epoch 71/300
# 1293/1293 [==============================] - ETA: 0s - loss: 1.0210 - accuracy: 0.4700
# Epoch 71: saving model to checkpoints_RS2_NN\model_epoch_71.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0210 - accuracy: 0.4700 - val_loss: 1.0184 - val_accuracy: 0.4750
# Epoch 72/300
# 1285/1293 [============================>.] - ETA: 0s - loss: 1.0207 - accuracy: 0.4710
# Epoch 72: saving model to checkpoints_RS2_NN\model_epoch_72.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0206 - accuracy: 0.4712 - val_loss: 1.0183 - val_accuracy: 0.4751
# Epoch 73/300
# 1291/1293 [============================>.] - ETA: 0s - loss: 1.0206 - accuracy: 0.4701
# Epoch 73: saving model to checkpoints_RS2_NN\model_epoch_73.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0206 - accuracy: 0.4701 - val_loss: 1.0182 - val_accuracy: 0.4746
# Epoch 74/300
# 1289/1293 [============================>.] - ETA: 0s - loss: 1.0208 - accuracy: 0.4710
# Epoch 74: saving model to checkpoints_RS2_NN\model_epoch_74.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0208 - accuracy: 0.4710 - val_loss: 1.0181 - val_accuracy: 0.4758
# Epoch 75/300
# 1292/1293 [============================>.] - ETA: 0s - loss: 1.0205 - accuracy: 0.4706
# Epoch 75: saving model to checkpoints_RS2_NN\model_epoch_75.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0205 - accuracy: 0.4706 - val_loss: 1.0179 - val_accuracy: 0.4755
# Epoch 76/300
# 1284/1293 [============================>.] - ETA: 0s - loss: 1.0200 - accuracy: 0.4711
# Epoch 76: saving model to checkpoints_RS2_NN\model_epoch_76.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0200 - accuracy: 0.4711 - val_loss: 1.0179 - val_accuracy: 0.4746
# Epoch 77/300
# 1288/1293 [============================>.] - ETA: 0s - loss: 1.0200 - accuracy: 0.4709
# Epoch 77: saving model to checkpoints_RS2_NN\model_epoch_77.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0200 - accuracy: 0.4710 - val_loss: 1.0178 - val_accuracy: 0.4756
# Epoch 78/300
# 1293/1293 [==============================] - ETA: 0s - loss: 1.0198 - accuracy: 0.4706
# Epoch 78: saving model to checkpoints_RS2_NN\model_epoch_78.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0198 - accuracy: 0.4706 - val_loss: 1.0177 - val_accuracy: 0.4752
# Epoch 79/300
# 1293/1293 [==============================] - ETA: 0s - loss: 1.0199 - accuracy: 0.4712
# Epoch 79: saving model to checkpoints_RS2_NN\model_epoch_79.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0199 - accuracy: 0.4712 - val_loss: 1.0176 - val_accuracy: 0.4753
# Epoch 80/300
# 1281/1293 [============================>.] - ETA: 0s - loss: 1.0199 - accuracy: 0.4715
# Epoch 80: saving model to checkpoints_RS2_NN\model_epoch_80.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0199 - accuracy: 0.4716 - val_loss: 1.0173 - val_accuracy: 0.4756
# Epoch 81/300
# 1291/1293 [============================>.] - ETA: 0s - loss: 1.0196 - accuracy: 0.4710
# Epoch 81: saving model to checkpoints_RS2_NN\model_epoch_81.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0196 - accuracy: 0.4710 - val_loss: 1.0172 - val_accuracy: 0.4757
# Epoch 82/300
# 1284/1293 [============================>.] - ETA: 0s - loss: 1.0192 - accuracy: 0.4713
# Epoch 82: saving model to checkpoints_RS2_NN\model_epoch_82.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0194 - accuracy: 0.4711 - val_loss: 1.0171 - val_accuracy: 0.4750
# Epoch 83/300
# 1284/1293 [============================>.] - ETA: 0s - loss: 1.0195 - accuracy: 0.4715
# Epoch 83: saving model to checkpoints_RS2_NN\model_epoch_83.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0194 - accuracy: 0.4717 - val_loss: 1.0171 - val_accuracy: 0.4757
# Epoch 84/300
# 1289/1293 [============================>.] - ETA: 0s - loss: 1.0194 - accuracy: 0.4719
# Epoch 84: saving model to checkpoints_RS2_NN\model_epoch_84.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0194 - accuracy: 0.4718 - val_loss: 1.0169 - val_accuracy: 0.4762
# Epoch 85/300
# 1284/1293 [============================>.] - ETA: 0s - loss: 1.0192 - accuracy: 0.4713
# Epoch 85: saving model to checkpoints_RS2_NN\model_epoch_85.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0194 - accuracy: 0.4712 - val_loss: 1.0168 - val_accuracy: 0.4749
# Epoch 86/300
# 1287/1293 [============================>.] - ETA: 0s - loss: 1.0192 - accuracy: 0.4709
# Epoch 86: saving model to checkpoints_RS2_NN\model_epoch_86.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0192 - accuracy: 0.4709 - val_loss: 1.0168 - val_accuracy: 0.4757
# Epoch 87/300
# 1284/1293 [============================>.] - ETA: 0s - loss: 1.0190 - accuracy: 0.4720
# Epoch 87: saving model to checkpoints_RS2_NN\model_epoch_87.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0192 - accuracy: 0.4719 - val_loss: 1.0168 - val_accuracy: 0.4749
# Epoch 88/300
# 1292/1293 [============================>.] - ETA: 0s - loss: 1.0192 - accuracy: 0.4715
# Epoch 88: saving model to checkpoints_RS2_NN\model_epoch_88.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0192 - accuracy: 0.4715 - val_loss: 1.0167 - val_accuracy: 0.4761
# Epoch 89/300
# 1293/1293 [==============================] - ETA: 0s - loss: 1.0183 - accuracy: 0.4714
# Epoch 89: saving model to checkpoints_RS2_NN\model_epoch_89.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0183 - accuracy: 0.4714 - val_loss: 1.0165 - val_accuracy: 0.4758
# Epoch 90/300
# 1284/1293 [============================>.] - ETA: 0s - loss: 1.0183 - accuracy: 0.4726
# Epoch 90: saving model to checkpoints_RS2_NN\model_epoch_90.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0182 - accuracy: 0.4728 - val_loss: 1.0164 - val_accuracy: 0.4755
# Epoch 91/300
# 1284/1293 [============================>.] - ETA: 0s - loss: 1.0187 - accuracy: 0.4712
# Epoch 91: saving model to checkpoints_RS2_NN\model_epoch_91.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0186 - accuracy: 0.4713 - val_loss: 1.0166 - val_accuracy: 0.4754
# Epoch 92/300
# 1290/1293 [============================>.] - ETA: 0s - loss: 1.0183 - accuracy: 0.4710
# Epoch 92: saving model to checkpoints_RS2_NN\model_epoch_92.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0183 - accuracy: 0.4710 - val_loss: 1.0165 - val_accuracy: 0.4756
# Epoch 93/300
# 1283/1293 [============================>.] - ETA: 0s - loss: 1.0181 - accuracy: 0.4724
# Epoch 93: saving model to checkpoints_RS2_NN\model_epoch_93.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0182 - accuracy: 0.4722 - val_loss: 1.0162 - val_accuracy: 0.4757
# Epoch 94/300
# 1285/1293 [============================>.] - ETA: 0s - loss: 1.0182 - accuracy: 0.4724
# Epoch 94: saving model to checkpoints_RS2_NN\model_epoch_94.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0181 - accuracy: 0.4725 - val_loss: 1.0161 - val_accuracy: 0.4758
# Epoch 95/300
# 1283/1293 [============================>.] - ETA: 0s - loss: 1.0184 - accuracy: 0.4726
# Epoch 95: saving model to checkpoints_RS2_NN\model_epoch_95.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0183 - accuracy: 0.4727 - val_loss: 1.0160 - val_accuracy: 0.4759
# Epoch 96/300
# 1283/1293 [============================>.] - ETA: 0s - loss: 1.0180 - accuracy: 0.4715
# Epoch 96: saving model to checkpoints_RS2_NN\model_epoch_96.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0181 - accuracy: 0.4715 - val_loss: 1.0160 - val_accuracy: 0.4759
# Epoch 97/300
# 1293/1293 [==============================] - ETA: 0s - loss: 1.0180 - accuracy: 0.4721
# Epoch 97: saving model to checkpoints_RS2_NN\model_epoch_97.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0180 - accuracy: 0.4721 - val_loss: 1.0159 - val_accuracy: 0.4757
# Epoch 98/300
# 1291/1293 [============================>.] - ETA: 0s - loss: 1.0182 - accuracy: 0.4722
# Epoch 98: saving model to checkpoints_RS2_NN\model_epoch_98.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0182 - accuracy: 0.4721 - val_loss: 1.0158 - val_accuracy: 0.4758
# Epoch 99/300
# 1285/1293 [============================>.] - ETA: 0s - loss: 1.0178 - accuracy: 0.4720
# Epoch 99: saving model to checkpoints_RS2_NN\model_epoch_99.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0178 - accuracy: 0.4720 - val_loss: 1.0158 - val_accuracy: 0.4758
# Epoch 100/300
# 1284/1293 [============================>.] - ETA: 0s - loss: 1.0182 - accuracy: 0.4704
# Epoch 100: saving model to checkpoints_RS2_NN\model_epoch_100.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0182 - accuracy: 0.4705 - val_loss: 1.0159 - val_accuracy: 0.4757
# Epoch 101/300
# 1289/1293 [============================>.] - ETA: 0s - loss: 1.0177 - accuracy: 0.4719
# Epoch 101: saving model to checkpoints_RS2_NN\model_epoch_101.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0177 - accuracy: 0.4719 - val_loss: 1.0158 - val_accuracy: 0.4757
# Epoch 102/300
# 1282/1293 [============================>.] - ETA: 0s - loss: 1.0177 - accuracy: 0.4720
# Epoch 102: saving model to checkpoints_RS2_NN\model_epoch_102.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0178 - accuracy: 0.4719 - val_loss: 1.0156 - val_accuracy: 0.4754
# Epoch 103/300
# 1290/1293 [============================>.] - ETA: 0s - loss: 1.0176 - accuracy: 0.4728
# Epoch 103: saving model to checkpoints_RS2_NN\model_epoch_103.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0176 - accuracy: 0.4727 - val_loss: 1.0155 - val_accuracy: 0.4756
# Epoch 104/300
# 1282/1293 [============================>.] - ETA: 0s - loss: 1.0176 - accuracy: 0.4722
# Epoch 104: saving model to checkpoints_RS2_NN\model_epoch_104.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0175 - accuracy: 0.4723 - val_loss: 1.0154 - val_accuracy: 0.4763
# Epoch 105/300
# 1286/1293 [============================>.] - ETA: 0s - loss: 1.0175 - accuracy: 0.4722
# Epoch 105: saving model to checkpoints_RS2_NN\model_epoch_105.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0174 - accuracy: 0.4724 - val_loss: 1.0155 - val_accuracy: 0.4770
# Epoch 106/300
# 1286/1293 [============================>.] - ETA: 0s - loss: 1.0172 - accuracy: 0.4733
# Epoch 106: saving model to checkpoints_RS2_NN\model_epoch_106.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0173 - accuracy: 0.4732 - val_loss: 1.0153 - val_accuracy: 0.4761
# Epoch 107/300
# 1290/1293 [============================>.] - ETA: 0s - loss: 1.0169 - accuracy: 0.4731
# Epoch 107: saving model to checkpoints_RS2_NN\model_epoch_107.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0169 - accuracy: 0.4731 - val_loss: 1.0155 - val_accuracy: 0.4761
# Epoch 108/300
# 1290/1293 [============================>.] - ETA: 0s - loss: 1.0173 - accuracy: 0.4725
# Epoch 108: saving model to checkpoints_RS2_NN\model_epoch_108.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0172 - accuracy: 0.4726 - val_loss: 1.0155 - val_accuracy: 0.4764
# Epoch 109/300
# 1288/1293 [============================>.] - ETA: 0s - loss: 1.0167 - accuracy: 0.4728
# Epoch 109: saving model to checkpoints_RS2_NN\model_epoch_109.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0168 - accuracy: 0.4728 - val_loss: 1.0151 - val_accuracy: 0.4755
# Epoch 110/300
# 1286/1293 [============================>.] - ETA: 0s - loss: 1.0171 - accuracy: 0.4730
# Epoch 110: saving model to checkpoints_RS2_NN\model_epoch_110.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0172 - accuracy: 0.4730 - val_loss: 1.0152 - val_accuracy: 0.4766
# Epoch 111/300
# 1281/1293 [============================>.] - ETA: 0s - loss: 1.0172 - accuracy: 0.4716
# Epoch 111: saving model to checkpoints_RS2_NN\model_epoch_111.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0173 - accuracy: 0.4715 - val_loss: 1.0151 - val_accuracy: 0.4758
# Epoch 112/300
# 1289/1293 [============================>.] - ETA: 0s - loss: 1.0173 - accuracy: 0.4724
# Epoch 112: saving model to checkpoints_RS2_NN\model_epoch_112.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0172 - accuracy: 0.4724 - val_loss: 1.0150 - val_accuracy: 0.4767
# Epoch 113/300
# 1288/1293 [============================>.] - ETA: 0s - loss: 1.0168 - accuracy: 0.4730
# Epoch 113: saving model to checkpoints_RS2_NN\model_epoch_113.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0167 - accuracy: 0.4730 - val_loss: 1.0150 - val_accuracy: 0.4765
# Epoch 114/300
# 1287/1293 [============================>.] - ETA: 0s - loss: 1.0169 - accuracy: 0.4727
# Epoch 114: saving model to checkpoints_RS2_NN\model_epoch_114.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0169 - accuracy: 0.4727 - val_loss: 1.0149 - val_accuracy: 0.4762
# Epoch 115/300
# 1287/1293 [============================>.] - ETA: 0s - loss: 1.0169 - accuracy: 0.4722
# Epoch 115: saving model to checkpoints_RS2_NN\model_epoch_115.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0169 - accuracy: 0.4722 - val_loss: 1.0148 - val_accuracy: 0.4763
# Epoch 116/300
# 1283/1293 [============================>.] - ETA: 0s - loss: 1.0166 - accuracy: 0.4738
# Epoch 116: saving model to checkpoints_RS2_NN\model_epoch_116.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0166 - accuracy: 0.4737 - val_loss: 1.0148 - val_accuracy: 0.4760
# Epoch 117/300
# 1290/1293 [============================>.] - ETA: 0s - loss: 1.0167 - accuracy: 0.4736
# Epoch 117: saving model to checkpoints_RS2_NN\model_epoch_117.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0167 - accuracy: 0.4736 - val_loss: 1.0148 - val_accuracy: 0.4766
# Epoch 118/300
# 1293/1293 [==============================] - ETA: 0s - loss: 1.0170 - accuracy: 0.4725
# Epoch 118: saving model to checkpoints_RS2_NN\model_epoch_118.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0170 - accuracy: 0.4725 - val_loss: 1.0147 - val_accuracy: 0.4774
# Epoch 119/300
# 1288/1293 [============================>.] - ETA: 0s - loss: 1.0165 - accuracy: 0.4732
# Epoch 119: saving model to checkpoints_RS2_NN\model_epoch_119.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0166 - accuracy: 0.4732 - val_loss: 1.0148 - val_accuracy: 0.4766
# Epoch 120/300
# 1285/1293 [============================>.] - ETA: 0s - loss: 1.0166 - accuracy: 0.4733
# Epoch 120: saving model to checkpoints_RS2_NN\model_epoch_120.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0165 - accuracy: 0.4734 - val_loss: 1.0153 - val_accuracy: 0.4761
# Epoch 121/300
# 1292/1293 [============================>.] - ETA: 0s - loss: 1.0163 - accuracy: 0.4739
# Epoch 121: saving model to checkpoints_RS2_NN\model_epoch_121.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0163 - accuracy: 0.4739 - val_loss: 1.0146 - val_accuracy: 0.4766
# Epoch 122/300
# 1285/1293 [============================>.] - ETA: 0s - loss: 1.0167 - accuracy: 0.4728
# Epoch 122: saving model to checkpoints_RS2_NN\model_epoch_122.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0167 - accuracy: 0.4727 - val_loss: 1.0146 - val_accuracy: 0.4772
# Epoch 123/300
# 1290/1293 [============================>.] - ETA: 0s - loss: 1.0163 - accuracy: 0.4736
# Epoch 123: saving model to checkpoints_RS2_NN\model_epoch_123.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0163 - accuracy: 0.4736 - val_loss: 1.0145 - val_accuracy: 0.4768
# Epoch 124/300
# 1284/1293 [============================>.] - ETA: 0s - loss: 1.0162 - accuracy: 0.4737
# Epoch 124: saving model to checkpoints_RS2_NN\model_epoch_124.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0162 - accuracy: 0.4737 - val_loss: 1.0144 - val_accuracy: 0.4767
# Epoch 125/300
# 1287/1293 [============================>.] - ETA: 0s - loss: 1.0160 - accuracy: 0.4731
# Epoch 125: saving model to checkpoints_RS2_NN\model_epoch_125.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0161 - accuracy: 0.4731 - val_loss: 1.0144 - val_accuracy: 0.4762
# Epoch 126/300
# 1284/1293 [============================>.] - ETA: 0s - loss: 1.0163 - accuracy: 0.4717
# Epoch 126: saving model to checkpoints_RS2_NN\model_epoch_126.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0163 - accuracy: 0.4717 - val_loss: 1.0144 - val_accuracy: 0.4765
# Epoch 127/300
# 1285/1293 [============================>.] - ETA: 0s - loss: 1.0164 - accuracy: 0.4727
# Epoch 127: saving model to checkpoints_RS2_NN\model_epoch_127.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0166 - accuracy: 0.4725 - val_loss: 1.0144 - val_accuracy: 0.4767
# Epoch 128/300
# 1286/1293 [============================>.] - ETA: 0s - loss: 1.0159 - accuracy: 0.4730
# Epoch 128: saving model to checkpoints_RS2_NN\model_epoch_128.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0160 - accuracy: 0.4730 - val_loss: 1.0145 - val_accuracy: 0.4769
# Epoch 129/300
# 1293/1293 [==============================] - ETA: 0s - loss: 1.0157 - accuracy: 0.4736
# Epoch 129: saving model to checkpoints_RS2_NN\model_epoch_129.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0157 - accuracy: 0.4736 - val_loss: 1.0144 - val_accuracy: 0.4774
# Epoch 130/300
# 1287/1293 [============================>.] - ETA: 0s - loss: 1.0160 - accuracy: 0.4726
# Epoch 130: saving model to checkpoints_RS2_NN\model_epoch_130.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0160 - accuracy: 0.4726 - val_loss: 1.0141 - val_accuracy: 0.4762
# Epoch 131/300
# 1287/1293 [============================>.] - ETA: 0s - loss: 1.0164 - accuracy: 0.4727
# Epoch 131: saving model to checkpoints_RS2_NN\model_epoch_131.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0163 - accuracy: 0.4728 - val_loss: 1.0142 - val_accuracy: 0.4765
# Epoch 132/300
# 1283/1293 [============================>.] - ETA: 0s - loss: 1.0161 - accuracy: 0.4724
# Epoch 132: saving model to checkpoints_RS2_NN\model_epoch_132.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0162 - accuracy: 0.4723 - val_loss: 1.0141 - val_accuracy: 0.4772
# Epoch 133/300
# 1287/1293 [============================>.] - ETA: 0s - loss: 1.0157 - accuracy: 0.4742
# Epoch 133: saving model to checkpoints_RS2_NN\model_epoch_133.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0156 - accuracy: 0.4741 - val_loss: 1.0141 - val_accuracy: 0.4763
# Epoch 134/300
# 1293/1293 [==============================] - ETA: 0s - loss: 1.0156 - accuracy: 0.4732
# Epoch 134: saving model to checkpoints_RS2_NN\model_epoch_134.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0156 - accuracy: 0.4732 - val_loss: 1.0140 - val_accuracy: 0.4765
# Epoch 135/300
# 1285/1293 [============================>.] - ETA: 0s - loss: 1.0158 - accuracy: 0.4732
# Epoch 135: saving model to checkpoints_RS2_NN\model_epoch_135.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0158 - accuracy: 0.4733 - val_loss: 1.0141 - val_accuracy: 0.4766
# Epoch 136/300
# 1288/1293 [============================>.] - ETA: 0s - loss: 1.0152 - accuracy: 0.4750
# Epoch 136: saving model to checkpoints_RS2_NN\model_epoch_136.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0153 - accuracy: 0.4751 - val_loss: 1.0140 - val_accuracy: 0.4761
# Epoch 137/300
# 1284/1293 [============================>.] - ETA: 0s - loss: 1.0152 - accuracy: 0.4743
# Epoch 137: saving model to checkpoints_RS2_NN\model_epoch_137.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0152 - accuracy: 0.4742 - val_loss: 1.0142 - val_accuracy: 0.4768
# Epoch 138/300
# 1283/1293 [============================>.] - ETA: 0s - loss: 1.0156 - accuracy: 0.4736
# Epoch 138: saving model to checkpoints_RS2_NN\model_epoch_138.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0156 - accuracy: 0.4734 - val_loss: 1.0139 - val_accuracy: 0.4766
# Epoch 139/300
# 1287/1293 [============================>.] - ETA: 0s - loss: 1.0156 - accuracy: 0.4724
# Epoch 139: saving model to checkpoints_RS2_NN\model_epoch_139.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0156 - accuracy: 0.4724 - val_loss: 1.0139 - val_accuracy: 0.4763
# Epoch 140/300
# 1289/1293 [============================>.] - ETA: 0s - loss: 1.0151 - accuracy: 0.4737
# Epoch 140: saving model to checkpoints_RS2_NN\model_epoch_140.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0152 - accuracy: 0.4737 - val_loss: 1.0140 - val_accuracy: 0.4783
# Epoch 141/300
# 1290/1293 [============================>.] - ETA: 0s - loss: 1.0154 - accuracy: 0.4733
# Epoch 141: saving model to checkpoints_RS2_NN\model_epoch_141.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0155 - accuracy: 0.4733 - val_loss: 1.0139 - val_accuracy: 0.4775
# Epoch 142/300
# 1286/1293 [============================>.] - ETA: 0s - loss: 1.0152 - accuracy: 0.4744
# Epoch 142: saving model to checkpoints_RS2_NN\model_epoch_142.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0152 - accuracy: 0.4744 - val_loss: 1.0138 - val_accuracy: 0.4772
# Epoch 143/300
# 1292/1293 [============================>.] - ETA: 0s - loss: 1.0151 - accuracy: 0.4733
# Epoch 143: saving model to checkpoints_RS2_NN\model_epoch_143.h5
# 1293/1293 [==============================] - 7s 5ms/step - loss: 1.0151 - accuracy: 0.4733 - val_loss: 1.0139 - val_accuracy: 0.4765
# Epoch 144/300
# 1288/1293 [============================>.] - ETA: 0s - loss: 1.0151 - accuracy: 0.4741
# Epoch 144: saving model to checkpoints_RS2_NN\model_epoch_144.h5
# 1293/1293 [==============================] - 7s 5ms/step - loss: 1.0152 - accuracy: 0.4740 - val_loss: 1.0137 - val_accuracy: 0.4772
# Epoch 145/300
# 1283/1293 [============================>.] - ETA: 0s - loss: 1.0153 - accuracy: 0.4737
# Epoch 145: saving model to checkpoints_RS2_NN\model_epoch_145.h5
# 1293/1293 [==============================] - 7s 5ms/step - loss: 1.0153 - accuracy: 0.4737 - val_loss: 1.0137 - val_accuracy: 0.4770
# Epoch 146/300
# 1286/1293 [============================>.] - ETA: 0s - loss: 1.0148 - accuracy: 0.4740
# Epoch 146: saving model to checkpoints_RS2_NN\model_epoch_146.h5
# 1293/1293 [==============================] - 7s 5ms/step - loss: 1.0148 - accuracy: 0.4739 - val_loss: 1.0136 - val_accuracy: 0.4769
# Epoch 147/300
# 1282/1293 [============================>.] - ETA: 0s - loss: 1.0153 - accuracy: 0.4740
# Epoch 147: saving model to checkpoints_RS2_NN\model_epoch_147.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0154 - accuracy: 0.4738 - val_loss: 1.0136 - val_accuracy: 0.4768
# Epoch 148/300
# 1289/1293 [============================>.] - ETA: 0s - loss: 1.0153 - accuracy: 0.4738
# Epoch 148: saving model to checkpoints_RS2_NN\model_epoch_148.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0153 - accuracy: 0.4739 - val_loss: 1.0136 - val_accuracy: 0.4777
# Epoch 149/300
# 1293/1293 [==============================] - ETA: 0s - loss: 1.0149 - accuracy: 0.4739
# Epoch 149: saving model to checkpoints_RS2_NN\model_epoch_149.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0149 - accuracy: 0.4739 - val_loss: 1.0135 - val_accuracy: 0.4762
# Epoch 150/300
# 1285/1293 [============================>.] - ETA: 0s - loss: 1.0150 - accuracy: 0.4736
# Epoch 150: saving model to checkpoints_RS2_NN\model_epoch_150.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0150 - accuracy: 0.4736 - val_loss: 1.0135 - val_accuracy: 0.4769
# Epoch 151/300
# 1285/1293 [============================>.] - ETA: 0s - loss: 1.0150 - accuracy: 0.4736
# Epoch 151: saving model to checkpoints_RS2_NN\model_epoch_151.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0149 - accuracy: 0.4738 - val_loss: 1.0134 - val_accuracy: 0.4773
# Epoch 152/300
# 1293/1293 [==============================] - ETA: 0s - loss: 1.0150 - accuracy: 0.4741
# Epoch 152: saving model to checkpoints_RS2_NN\model_epoch_152.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0150 - accuracy: 0.4741 - val_loss: 1.0134 - val_accuracy: 0.4768
# Epoch 153/300
# 1287/1293 [============================>.] - ETA: 0s - loss: 1.0148 - accuracy: 0.4743
# Epoch 153: saving model to checkpoints_RS2_NN\model_epoch_153.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0149 - accuracy: 0.4742 - val_loss: 1.0134 - val_accuracy: 0.4762
# Epoch 154/300
# 1293/1293 [==============================] - ETA: 0s - loss: 1.0149 - accuracy: 0.4743
# Epoch 154: saving model to checkpoints_RS2_NN\model_epoch_154.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0149 - accuracy: 0.4743 - val_loss: 1.0134 - val_accuracy: 0.4775
# Epoch 155/300
# 1286/1293 [============================>.] - ETA: 0s - loss: 1.0147 - accuracy: 0.4748
# Epoch 155: saving model to checkpoints_RS2_NN\model_epoch_155.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0148 - accuracy: 0.4748 - val_loss: 1.0135 - val_accuracy: 0.4771
# Epoch 156/300
# 1288/1293 [============================>.] - ETA: 0s - loss: 1.0145 - accuracy: 0.4744
# Epoch 156: saving model to checkpoints_RS2_NN\model_epoch_156.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0146 - accuracy: 0.4744 - val_loss: 1.0134 - val_accuracy: 0.4774
# Epoch 157/300
# 1289/1293 [============================>.] - ETA: 0s - loss: 1.0148 - accuracy: 0.4746
# Epoch 157: saving model to checkpoints_RS2_NN\model_epoch_157.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0149 - accuracy: 0.4745 - val_loss: 1.0133 - val_accuracy: 0.4771
# Epoch 158/300
# 1289/1293 [============================>.] - ETA: 0s - loss: 1.0146 - accuracy: 0.4742
# Epoch 158: saving model to checkpoints_RS2_NN\model_epoch_158.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0146 - accuracy: 0.4743 - val_loss: 1.0133 - val_accuracy: 0.4771
# Epoch 159/300
# 1289/1293 [============================>.] - ETA: 0s - loss: 1.0149 - accuracy: 0.4742
# Epoch 159: saving model to checkpoints_RS2_NN\model_epoch_159.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0149 - accuracy: 0.4741 - val_loss: 1.0132 - val_accuracy: 0.4774
# Epoch 160/300
# 1283/1293 [============================>.] - ETA: 0s - loss: 1.0146 - accuracy: 0.4737
# Epoch 160: saving model to checkpoints_RS2_NN\model_epoch_160.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0147 - accuracy: 0.4734 - val_loss: 1.0133 - val_accuracy: 0.4775
# Epoch 161/300
# 1289/1293 [============================>.] - ETA: 0s - loss: 1.0147 - accuracy: 0.4751
# Epoch 161: saving model to checkpoints_RS2_NN\model_epoch_161.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0147 - accuracy: 0.4750 - val_loss: 1.0131 - val_accuracy: 0.4774
# Epoch 162/300
# 1286/1293 [============================>.] - ETA: 0s - loss: 1.0142 - accuracy: 0.4752
# Epoch 162: saving model to checkpoints_RS2_NN\model_epoch_162.h5
# ...
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0124 - accuracy: 0.4756 - val_loss: 1.0115 - val_accuracy: 0.4783
# Epoch 248/300
# 1283/1293 [============================>.] - ETA: 0s - loss: 1.0124 - accuracy: 0.4750
# Epoch 248: saving model to checkpoints_RS2_NN\model_epoch_248.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0124 - accuracy: 0.4751 - val_loss: 1.0116 - val_accuracy: 0.4784
# Epoch 249/300
# 1290/1293 [============================>.] - ETA: 0s - loss: 1.0121 - accuracy: 0.4766
# Epoch 249: saving model to checkpoints_RS2_NN\model_epoch_249.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0121 - accuracy: 0.4766 - val_loss: 1.0116 - val_accuracy: 0.4779
# Epoch 250/300
# 1284/1293 [============================>.] - ETA: 0s - loss: 1.0121 - accuracy: 0.4751
# Epoch 250: saving model to checkpoints_RS2_NN\model_epoch_250.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0122 - accuracy: 0.4751 - val_loss: 1.0116 - val_accuracy: 0.4776
# Epoch 251/300
# 1283/1293 [============================>.] - ETA: 0s - loss: 1.0120 - accuracy: 0.4760
# Epoch 251: saving model to checkpoints_RS2_NN\model_epoch_251.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0120 - accuracy: 0.4760 - val_loss: 1.0118 - val_accuracy: 0.4780
# Epoch 252/300
# 1290/1293 [============================>.] - ETA: 0s - loss: 1.0118 - accuracy: 0.4759
# Epoch 252: saving model to checkpoints_RS2_NN\model_epoch_252.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0118 - accuracy: 0.4758 - val_loss: 1.0115 - val_accuracy: 0.4779
# Epoch 253/300
# 1286/1293 [============================>.] - ETA: 0s - loss: 1.0117 - accuracy: 0.4760
# Epoch 253: saving model to checkpoints_RS2_NN\model_epoch_253.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0117 - accuracy: 0.4759 - val_loss: 1.0116 - val_accuracy: 0.4781
# Epoch 254/300
# 1292/1293 [============================>.] - ETA: 0s - loss: 1.0123 - accuracy: 0.4758
# Epoch 254: saving model to checkpoints_RS2_NN\model_epoch_254.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0123 - accuracy: 0.4758 - val_loss: 1.0114 - val_accuracy: 0.4772
# Epoch 255/300
# 1293/1293 [==============================] - ETA: 0s - loss: 1.0122 - accuracy: 0.4756
# Epoch 255: saving model to checkpoints_RS2_NN\model_epoch_255.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0122 - accuracy: 0.4756 - val_loss: 1.0114 - val_accuracy: 0.4778
# Epoch 256/300
# 1287/1293 [============================>.] - ETA: 0s - loss: 1.0119 - accuracy: 0.4765
# Epoch 256: saving model to checkpoints_RS2_NN\model_epoch_256.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0120 - accuracy: 0.4765 - val_loss: 1.0116 - val_accuracy: 0.4769
# Epoch 257/300
# 1288/1293 [============================>.] - ETA: 0s - loss: 1.0123 - accuracy: 0.4751
# Epoch 257: saving model to checkpoints_RS2_NN\model_epoch_257.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0123 - accuracy: 0.4752 - val_loss: 1.0114 - val_accuracy: 0.4779
# Epoch 258/300
# 1292/1293 [============================>.] - ETA: 0s - loss: 1.0118 - accuracy: 0.4759
# Epoch 258: saving model to checkpoints_RS2_NN\model_epoch_258.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0118 - accuracy: 0.4759 - val_loss: 1.0113 - val_accuracy: 0.4780
# Epoch 259/300
# 1292/1293 [============================>.] - ETA: 0s - loss: 1.0121 - accuracy: 0.4752
# Epoch 259: saving model to checkpoints_RS2_NN\model_epoch_259.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0121 - accuracy: 0.4752 - val_loss: 1.0114 - val_accuracy: 0.4776
# Epoch 260/300
# 1286/1293 [============================>.] - ETA: 0s - loss: 1.0118 - accuracy: 0.4767
# Epoch 260: saving model to checkpoints_RS2_NN\model_epoch_260.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0118 - accuracy: 0.4767 - val_loss: 1.0114 - val_accuracy: 0.4777
# Epoch 261/300
# 1286/1293 [============================>.] - ETA: 0s - loss: 1.0118 - accuracy: 0.4760
# Epoch 261: saving model to checkpoints_RS2_NN\model_epoch_261.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0118 - accuracy: 0.4760 - val_loss: 1.0115 - val_accuracy: 0.4773
# Epoch 262/300
# 1286/1293 [============================>.] - ETA: 0s - loss: 1.0116 - accuracy: 0.4765
# Epoch 262: saving model to checkpoints_RS2_NN\model_epoch_262.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0116 - accuracy: 0.4764 - val_loss: 1.0113 - val_accuracy: 0.4775
# Epoch 263/300
# 1284/1293 [============================>.] - ETA: 0s - loss: 1.0117 - accuracy: 0.4761
# Epoch 263: saving model to checkpoints_RS2_NN\model_epoch_263.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0118 - accuracy: 0.4760 - val_loss: 1.0114 - val_accuracy: 0.4781
# Epoch 264/300
# 1290/1293 [============================>.] - ETA: 0s - loss: 1.0121 - accuracy: 0.4759
# Epoch 264: saving model to checkpoints_RS2_NN\model_epoch_264.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0120 - accuracy: 0.4759 - val_loss: 1.0113 - val_accuracy: 0.4775
# Epoch 265/300
# 1292/1293 [============================>.] - ETA: 0s - loss: 1.0117 - accuracy: 0.4758
# Epoch 265: saving model to checkpoints_RS2_NN\model_epoch_265.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0117 - accuracy: 0.4758 - val_loss: 1.0115 - val_accuracy: 0.4783
# Epoch 266/300
# 1285/1293 [============================>.] - ETA: 0s - loss: 1.0118 - accuracy: 0.4764
# Epoch 266: saving model to checkpoints_RS2_NN\model_epoch_266.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0117 - accuracy: 0.4766 - val_loss: 1.0113 - val_accuracy: 0.4784
# Epoch 267/300
# 1292/1293 [============================>.] - ETA: 0s - loss: 1.0113 - accuracy: 0.4770
# Epoch 267: saving model to checkpoints_RS2_NN\model_epoch_267.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0113 - accuracy: 0.4770 - val_loss: 1.0116 - val_accuracy: 0.4772
# Epoch 268/300
# 1281/1293 [============================>.] - ETA: 0s - loss: 1.0119 - accuracy: 0.4764
# Epoch 268: saving model to checkpoints_RS2_NN\model_epoch_268.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0118 - accuracy: 0.4767 - val_loss: 1.0115 - val_accuracy: 0.4780
# Epoch 269/300
# 1284/1293 [============================>.] - ETA: 0s - loss: 1.0119 - accuracy: 0.4757
# Epoch 269: saving model to checkpoints_RS2_NN\model_epoch_269.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0117 - accuracy: 0.4759 - val_loss: 1.0114 - val_accuracy: 0.4778
# Epoch 270/300
# 1290/1293 [============================>.] - ETA: 0s - loss: 1.0117 - accuracy: 0.4757
# Epoch 270: saving model to checkpoints_RS2_NN\model_epoch_270.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0117 - accuracy: 0.4756 - val_loss: 1.0115 - val_accuracy: 0.4770
# Epoch 271/300
# 1285/1293 [============================>.] - ETA: 0s - loss: 1.0116 - accuracy: 0.4759
# Epoch 271: saving model to checkpoints_RS2_NN\model_epoch_271.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0116 - accuracy: 0.4760 - val_loss: 1.0115 - val_accuracy: 0.4776
# Epoch 272/300
# 1282/1293 [============================>.] - ETA: 0s - loss: 1.0120 - accuracy: 0.4761
# Epoch 272: saving model to checkpoints_RS2_NN\model_epoch_272.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0119 - accuracy: 0.4761 - val_loss: 1.0117 - val_accuracy: 0.4770
# Epoch 273/300
# 1285/1293 [============================>.] - ETA: 0s - loss: 1.0116 - accuracy: 0.4762
# Epoch 273: saving model to checkpoints_RS2_NN\model_epoch_273.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0115 - accuracy: 0.4762 - val_loss: 1.0112 - val_accuracy: 0.4772
# Epoch 274/300
# 1287/1293 [============================>.] - ETA: 0s - loss: 1.0114 - accuracy: 0.4755
# Epoch 274: saving model to checkpoints_RS2_NN\model_epoch_274.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0114 - accuracy: 0.4755 - val_loss: 1.0112 - val_accuracy: 0.4777
# Epoch 275/300
# 1289/1293 [============================>.] - ETA: 0s - loss: 1.0116 - accuracy: 0.4760
# Epoch 275: saving model to checkpoints_RS2_NN\model_epoch_275.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0115 - accuracy: 0.4762 - val_loss: 1.0112 - val_accuracy: 0.4780
# Epoch 276/300
# 1292/1293 [============================>.] - ETA: 0s - loss: 1.0117 - accuracy: 0.4767
# Epoch 276: saving model to checkpoints_RS2_NN\model_epoch_276.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0117 - accuracy: 0.4767 - val_loss: 1.0112 - val_accuracy: 0.4777
# Epoch 277/300
# 1287/1293 [============================>.] - ETA: 0s - loss: 1.0116 - accuracy: 0.4768
# Epoch 277: saving model to checkpoints_RS2_NN\model_epoch_277.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0115 - accuracy: 0.4768 - val_loss: 1.0114 - val_accuracy: 0.4781
# Epoch 278/300
# 1283/1293 [============================>.] - ETA: 0s - loss: 1.0114 - accuracy: 0.4759
# Epoch 278: saving model to checkpoints_RS2_NN\model_epoch_278.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0115 - accuracy: 0.4759 - val_loss: 1.0112 - val_accuracy: 0.4776
# Epoch 279/300
# 1289/1293 [============================>.] - ETA: 0s - loss: 1.0116 - accuracy: 0.4759
# Epoch 279: saving model to checkpoints_RS2_NN\model_epoch_279.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0116 - accuracy: 0.4759 - val_loss: 1.0111 - val_accuracy: 0.4784
# Epoch 280/300
# 1283/1293 [============================>.] - ETA: 0s - loss: 1.0116 - accuracy: 0.4758
# Epoch 280: saving model to checkpoints_RS2_NN\model_epoch_280.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0116 - accuracy: 0.4758 - val_loss: 1.0110 - val_accuracy: 0.4788
# Epoch 281/300
# 1283/1293 [============================>.] - ETA: 0s - loss: 1.0113 - accuracy: 0.4757
# Epoch 281: saving model to checkpoints_RS2_NN\model_epoch_281.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0112 - accuracy: 0.4758 - val_loss: 1.0112 - val_accuracy: 0.4772
# Epoch 282/300
# 1281/1293 [============================>.] - ETA: 0s - loss: 1.0111 - accuracy: 0.4766
# Epoch 282: saving model to checkpoints_RS2_NN\model_epoch_282.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0111 - accuracy: 0.4765 - val_loss: 1.0114 - val_accuracy: 0.4773
# Epoch 283/300
# 1288/1293 [============================>.] - ETA: 0s - loss: 1.0112 - accuracy: 0.4773
# Epoch 283: saving model to checkpoints_RS2_NN\model_epoch_283.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0113 - accuracy: 0.4772 - val_loss: 1.0111 - val_accuracy: 0.4783
# Epoch 284/300
# 1284/1293 [============================>.] - ETA: 0s - loss: 1.0117 - accuracy: 0.4759
# Epoch 284: saving model to checkpoints_RS2_NN\model_epoch_284.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0117 - accuracy: 0.4759 - val_loss: 1.0111 - val_accuracy: 0.4784
# Epoch 285/300
# 1284/1293 [============================>.] - ETA: 0s - loss: 1.0112 - accuracy: 0.4768
# Epoch 285: saving model to checkpoints_RS2_NN\model_epoch_285.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0112 - accuracy: 0.4767 - val_loss: 1.0112 - val_accuracy: 0.4775
# Epoch 286/300
# 1287/1293 [============================>.] - ETA: 0s - loss: 1.0113 - accuracy: 0.4767
# Epoch 286: saving model to checkpoints_RS2_NN\model_epoch_286.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0113 - accuracy: 0.4768 - val_loss: 1.0110 - val_accuracy: 0.4781
# Epoch 287/300
# 1290/1293 [============================>.] - ETA: 0s - loss: 1.0116 - accuracy: 0.4765
# Epoch 287: saving model to checkpoints_RS2_NN\model_epoch_287.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0116 - accuracy: 0.4764 - val_loss: 1.0110 - val_accuracy: 0.4784
# Epoch 288/300
# 1290/1293 [============================>.] - ETA: 0s - loss: 1.0114 - accuracy: 0.4770
# Epoch 288: saving model to checkpoints_RS2_NN\model_epoch_288.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0114 - accuracy: 0.4770 - val_loss: 1.0110 - val_accuracy: 0.4789
# Epoch 289/300
# 1291/1293 [============================>.] - ETA: 0s - loss: 1.0115 - accuracy: 0.4760
# Epoch 289: saving model to checkpoints_RS2_NN\model_epoch_289.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0115 - accuracy: 0.4760 - val_loss: 1.0110 - val_accuracy: 0.4774
# Epoch 290/300
# 1284/1293 [============================>.] - ETA: 0s - loss: 1.0114 - accuracy: 0.4761
# Epoch 290: saving model to checkpoints_RS2_NN\model_epoch_290.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0114 - accuracy: 0.4761 - val_loss: 1.0110 - val_accuracy: 0.4781
# Epoch 291/300
# 1291/1293 [============================>.] - ETA: 0s - loss: 1.0116 - accuracy: 0.4762
# Epoch 291: saving model to checkpoints_RS2_NN\model_epoch_291.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0116 - accuracy: 0.4762 - val_loss: 1.0111 - val_accuracy: 0.4771
# Epoch 292/300
# 1286/1293 [============================>.] - ETA: 0s - loss: 1.0112 - accuracy: 0.4768
# Epoch 292: saving model to checkpoints_RS2_NN\model_epoch_292.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0111 - accuracy: 0.4769 - val_loss: 1.0110 - val_accuracy: 0.4778
# Epoch 293/300
# 1288/1293 [============================>.] - ETA: 0s - loss: 1.0114 - accuracy: 0.4764
# Epoch 293: saving model to checkpoints_RS2_NN\model_epoch_293.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0114 - accuracy: 0.4764 - val_loss: 1.0110 - val_accuracy: 0.4781
# Epoch 294/300
# 1292/1293 [============================>.] - ETA: 0s - loss: 1.0114 - accuracy: 0.4767
# Epoch 294: saving model to checkpoints_RS2_NN\model_epoch_294.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0114 - accuracy: 0.4766 - val_loss: 1.0111 - val_accuracy: 0.4781
# Epoch 295/300
# 1282/1293 [============================>.] - ETA: 0s - loss: 1.0113 - accuracy: 0.4754
# Epoch 295: saving model to checkpoints_RS2_NN\model_epoch_295.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0113 - accuracy: 0.4753 - val_loss: 1.0110 - val_accuracy: 0.4788
# Epoch 296/300
# 1282/1293 [============================>.] - ETA: 0s - loss: 1.0112 - accuracy: 0.4764
# Epoch 296: saving model to checkpoints_RS2_NN\model_epoch_296.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0112 - accuracy: 0.4765 - val_loss: 1.0110 - val_accuracy: 0.4779
# Epoch 297/300
# 1290/1293 [============================>.] - ETA: 0s - loss: 1.0113 - accuracy: 0.4764
# Epoch 297: saving model to checkpoints_RS2_NN\model_epoch_297.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0113 - accuracy: 0.4763 - val_loss: 1.0112 - val_accuracy: 0.4777
# Epoch 298/300
# 1292/1293 [============================>.] - ETA: 0s - loss: 1.0111 - accuracy: 0.4771
# Epoch 298: saving model to checkpoints_RS2_NN\model_epoch_298.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0111 - accuracy: 0.4771 - val_loss: 1.0110 - val_accuracy: 0.4779
# Epoch 299/300
# 1284/1293 [============================>.] - ETA: 0s - loss: 1.0113 - accuracy: 0.4770
# Epoch 299: saving model to checkpoints_RS2_NN\model_epoch_299.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0113 - accuracy: 0.4771 - val_loss: 1.0110 - val_accuracy: 0.4786
# Epoch 300/300
# 1290/1293 [============================>.] - ETA: 0s - loss: 1.0113 - accuracy: 0.4763
# Epoch 300: saving model to checkpoints_RS2_NN\model_epoch_300.h5
# 1293/1293 [==============================] - 6s 5ms/step - loss: 1.0113 - accuracy: 0.4764 - val_loss: 1.0109 - val_accuracy: 0.4773

# %%
#plot the training history
plt.rcParams['font.family'] = 'serif'
plt.rcParams['font.size'] = 12

plt.figure(figsize=(12,4), dpi = 150)

plt.subplot(1,2,1)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend()
plt.title('Loss evolution')

plt.subplot(1,2,2)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')

plt.legend()
plt.title('Accuracy evolution')

plt.show()

# %%
#display the epoch with the lowest validation loss
min_val_loss = min(history.history['val_loss'])
min_val_loss_epoch = np.argmin(history.history['val_loss']) + 1
print(f"Minimum validation loss of {min_val_loss} reached at epoch {min_val_loss_epoch}")
# Out:
# Minimum validation loss of 1.0109426975250244 reached at epoch 300

# %%
#load the model with the lowest validation loss
from tensorflow.keras.models import load_model
model = load_model('checkpoints_RS2_NN/model_epoch_300.h5')

# %%
#predict the class of the test set and display the accuracy
pred = np.argmax(model.predict(X_test), axis=1)
print("Accuracy: {}".format(accuracy_score(y_test, pred)))
# Out:
# 981/981 [==============================] - 3s 1ms/step
# Accuracy: 0.5023101679253099

# %%
#insert the prediction values into the database

data_tuples = [(float(element[0]), float(element[1]), float(element[2])) for element in model.predict(X_test)]
cursor.execute("DROP TABLE IF EXISTS temp_table")
cursor.execute("""
    CREATE TEMPORARY TABLE temp_table (
        id SERIAL PRIMARY KEY,
        nn_0 FLOAT,
        nn_1 FLOAT,
        nn_2 FLOAT
    )
""")
query = "INSERT INTO temp_table (nn_0, nn_1, nn_2) VALUES (%s, %s, %s);"
cursor.executemany(query, data_tuples)
cursor.execute("""
    UPDATE rq2_test_predictions 
    JOIN temp_table 
    ON rq2_test_predictions.id = temp_table.id
    SET 
        rq2_test_predictions.nn_0 = temp_table.nn_0, 
        rq2_test_predictions.nn_1 = temp_table.nn_1, 
        rq2_test_predictions.nn_2 = temp_table.nn_2
""")
db_connection.commit()
# Out:
#  24/981 [..............................] - ETA: 2s
# 981/981 [==============================] - 1s 2ms/step
